# %%
import pandas as pd

# %%
df_buses_1=pd.read_csv("df_buses_1.csv")
df_buses_2=pd.read_csv("df_buses_2.csv")
df_buses_3=pd.read_csv("df_buses_3.csv")
df_buses_4=pd.read_csv("df_buses_4.csv")
df_buses_5=pd.read_csv("df_buses_5.csv")
df_buses_6=pd.read_csv("df_buses_6.csv")
df_buses_7=pd.read_csv("df_buses_7.csv")
df_buses_8=pd.read_csv("df_buses_8.csv")
df_buses_9=pd.read_csv("df_buses_9.csv")
df_buses_10=pd.read_csv("df_buses_10.csv")

Final_df=pd.concat([df_buses_1,df_buses_2,df_buses_3,df_buses_4,df_buses_5,df_buses_6,df_buses_7,df_buses_8,df_buses_9,df_buses_10],ignore_index=True)
Final_df
# Out:
#                    Bus_name                                   Bus_type  \
# 0       KSRTC (Kerala) - 51          Swift Deluxe Non AC Air Bus (2+2)
# 1      KSRTC (Kerala) - 789             Super Fast Non AC Seater (2+3)
# 2     KSRTC (Kerala) - 1585  Super Express Non AC Seater Air Bus (2+2)
# 3     KSRTC (Kerala) - 1586  Super Express Non AC Seater Air Bus (2+2)
# 4     KSRTC (Kerala) - 2133          Swift Deluxe Non AC Air Bus (2+2)
# ...                     ...                                        ...
# 2657         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
# 2658         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
# 2659           Zingbus Plus          Volvo 9600 A/C Semi Sleeper (2+2)
# 2660    AdIntrCity SmartBus          Volvo 9600 A/C Semi Sleeper (2+2)
# 2661         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
#
#      Start_time End_time Total_duration    Price     Seats_Available  \
# ...

# %%
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2662 entries, 0 to 2661
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         2662 non-null   object
#  1   Bus_type         2662 non-null   object
#  2   Start_time       2662 non-null   object
#  3   End_time         2662 non-null   object
#  4   Total_duration   2662 non-null   object
#  5   Price            2662 non-null   object
#  6   Seats_Available  2662 non-null   object
#  7   Ratings          2662 non-null   object
#  8   Route_link       2662 non-null   object
#  9   Route_name       2662 non-null   object
# dtypes: object(10)
# memory usage: 208.1+ KB

# %%
Final_df["Price"]=Final_df["Price"].str.replace("INR","")
Final_df["Price"]=Final_df["Price"].astype(int)
Final_df["Price"].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 Final_df["Price"]=Final_df["Price"].str.replace("INR","")
# ----> 2 Final_df["Price"]=Final_df["Price"].astype(int)
#       3 Final_df["Price"].fillna(0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
Final_df["Price"] = Final_df["Price"].str.replace("INR", "", regex=False)
Final_df["Price"] = Final_df["Price"].str.replace(",", "", regex=False)  # Remove commas if present

# Convert to numeric, handling any non-convertible values
Final_df["Price"] = pd.to_numeric(Final_df["Price"], errors='coerce').fillna(0).astype(int)

# %%
Final_df
# Out:
#                    Bus_name                                   Bus_type  \
# 0       KSRTC (Kerala) - 51          Swift Deluxe Non AC Air Bus (2+2)
# 1      KSRTC (Kerala) - 789             Super Fast Non AC Seater (2+3)
# 2     KSRTC (Kerala) - 1585  Super Express Non AC Seater Air Bus (2+2)
# 3     KSRTC (Kerala) - 1586  Super Express Non AC Seater Air Bus (2+2)
# 4     KSRTC (Kerala) - 2133          Swift Deluxe Non AC Air Bus (2+2)
# ...                     ...                                        ...
# 2657         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
# 2658         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
# 2659           Zingbus Plus          Volvo 9600 A/C Semi Sleeper (2+2)
# 2660    AdIntrCity SmartBus          Volvo 9600 A/C Semi Sleeper (2+2)
# 2661         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
#
#      Start_time End_time Total_duration  Price     Seats_Available   Ratings  \
# ...

# %%
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2662 entries, 0 to 2661
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         2662 non-null   object
#  1   Bus_type         2662 non-null   object
#  2   Start_time       2662 non-null   object
#  3   End_time         2662 non-null   object
#  4   Total_duration   2662 non-null   object
#  5   Price            2662 non-null   int32
#  6   Seats_Available  2662 non-null   object
#  7   Ratings          2662 non-null   object
#  8   Route_link       2662 non-null   object
#  9   Route_name       2662 non-null   object
# dtypes: int32(1), object(9)
# memory usage: 197.7+ KB

# %%
Final_df["Ratings"]=Final_df["Ratings"].str.replace("New","")
Final_df["Ratings"]=Final_df["Ratings"].str.strip()
Final_df["Ratings"]=Final_df["Ratings"].str.split().str[0]
Final_df["Ratings"]=pd.to_numeric(Final_df["Ratings"],errors='coerce')
Final_df["Ratings"].fillna(0)
# Out:
# 0       4.1
# 1       3.9
# 2       3.4
# 3       3.7
# 4       4.1
#        ...
# 2657    4.7
# 2658    4.6
# 2659    4.8
# 2660    4.6
# 2661    4.6
# Name: Ratings, Length: 2662, dtype: float64

# %%
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2662 entries, 0 to 2661
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         2662 non-null   object
#  1   Bus_type         2662 non-null   object
#  2   Start_time       2662 non-null   object
#  3   End_time         2662 non-null   object
#  4   Total_duration   2662 non-null   object
#  5   Price            2662 non-null   int32
#  6   Seats_Available  2662 non-null   object
#  7   Ratings          2640 non-null   float64
#  8   Route_link       2662 non-null   object
#  9   Route_name       2662 non-null   object
# dtypes: float64(1), int32(1), object(8)
# memory usage: 197.7+ KB

# %%
import numpy as np
Final_df= Final_df.replace({np.nan: None})

# %%
Final_df
# Out:
#                    Bus_name                                   Bus_type  \
# 0       KSRTC (Kerala) - 51          Swift Deluxe Non AC Air Bus (2+2)
# 1      KSRTC (Kerala) - 789             Super Fast Non AC Seater (2+3)
# 2     KSRTC (Kerala) - 1585  Super Express Non AC Seater Air Bus (2+2)
# 3     KSRTC (Kerala) - 1586  Super Express Non AC Seater Air Bus (2+2)
# 4     KSRTC (Kerala) - 2133          Swift Deluxe Non AC Air Bus (2+2)
# ...                     ...                                        ...
# 2657         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
# 2658         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
# 2659           Zingbus Plus          Volvo 9600 A/C Semi Sleeper (2+2)
# 2660    AdIntrCity SmartBus          Volvo 9600 A/C Semi Sleeper (2+2)
# 2661         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
#
#      Start_time End_time Total_duration  Price     Seats_Available Ratings  \
# ...

# %%
path="Final_df.csv"
df=Final_df.to_csv(path,index=False)

# %%
import pandas as pd
FX=pd.read_csv("Final_df.csv")
FX
# Out:
#                    Bus_name                                   Bus_type  \
# 0       KSRTC (Kerala) - 51          Swift Deluxe Non AC Air Bus (2+2)
# 1      KSRTC (Kerala) - 789             Super Fast Non AC Seater (2+3)
# 2     KSRTC (Kerala) - 1585  Super Express Non AC Seater Air Bus (2+2)
# 3     KSRTC (Kerala) - 1586  Super Express Non AC Seater Air Bus (2+2)
# 4     KSRTC (Kerala) - 2133          Swift Deluxe Non AC Air Bus (2+2)
# ...                     ...                                        ...
# 2657         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
# 2658         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
# 2659           Zingbus Plus          Volvo 9600 A/C Semi Sleeper (2+2)
# 2660    AdIntrCity SmartBus          Volvo 9600 A/C Semi Sleeper (2+2)
# 2661         Laxmi holidays          Volvo 9600 A/C Semi Sleeper (2+2)
#
#      Start_time End_time Total_duration  Price     Seats_Available  Ratings  \
# ...

# %%
# !pip3 install mysql-connector-python

# %%
import mysql.connector
mydb=mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
)

# %%
mydb

# %%
mycursor=mydb.cursor(buffered=True)

# %%
mycursor.execute("Show databases")
for x in mycursor:
    print(x)
# Out:
# ('information_schema',)
# ('mdt37',)
# ('mdt38',)
# ('mdt39',)
# ('mdt42',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('redbus_details',)
# ('sri39',)
# ('test',)

# %%
mycursor.execute("Use redbus_details")

# %%
mycursor.execute('''Create Table bus_details( 
                 ID INT AUTO_INCREMENT PRIMARY KEY NOT NULL,
                 Bus_name VARCHAR(255),
                 Bus_type VARCHAR(255),
                 Start_time VARCHAR(255),
                 End_time VARCHAR(255),
                 Total_duration VARCHAR(255),
                 Price INT,
                 Seats_Available VARCHAR(255),
                 Ratings Float,
                 Route_link VARCHAR(255),
                 Route_name VARCHAR(255)
                 )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
insert_query = '''INSERT INTO bus_details(
                    Bus_name,
                    Bus_type,
                    Start_time,
                    End_time,
                    Total_duration,
                    Price,
                    Seats_Available,
                    Ratings,
                    Route_link,
                    Route_name)
                  VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
data= Final_df.values.tolist()

mycursor.executemany(insert_query,data)

mydb.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully
