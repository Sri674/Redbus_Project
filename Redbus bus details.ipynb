# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\sridhar\anaconda3\lib\site-packages (4.24.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sridhar\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.2)
# Requirement already satisfied: trio~=0.17 in c:\users\sridhar\anaconda3\lib\site-packages (from selenium) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\sridhar\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\sridhar\anaconda3\lib\site-packages (from selenium) (2024.7.4)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\sridhar\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\sridhar\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\sridhar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\sridhar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\sridhar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\sridhar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\sridhar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\sridhar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\sridhar\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sridhar\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\sridhar\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\sridhar\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
                             #KERALA BUS DETAILS

import pandas as pd
KX=pd.read_csv("dfk.csv")
KX
# Out:
#                          Route_name  \
# 0            Bangalore to Kozhikode
# 1            Kozhikode to Bangalore
# 2            Kozhikode to Ernakulam
# 3            Ernakulam to Kozhikode
# 4               Bangalore to Kannur
# 5               Kozhikode to Mysore
# 6               Kannur to Bangalore
# 7   Kozhikode to Thiruvananthapuram
# 8               Mysore to Kozhikode
# 9    Bangalore to Kalpetta (kerala)
# 10   Kalpetta (kerala) to Bangalore
# 11  Thiruvananthapuram to Kozhikode
# 12            Kozhikode to Thrissur
# 13            Kozhikode to Kottayam
# 14            Kottayam to Kozhikode
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/bangalore-to...
# 1   https://www.redbus.in/bus-tickets/kozhikode-to...
# 2   https://www.redbus.in/bus-tickets/kozhikode-to...
# 3   https://www.redbus.in/bus-tickets/ernakulam-to...
# 4   https://www.redbus.in/bus-tickets/bangalore-to...
# 5   https://www.redbus.in/bus-tickets/kozhikode-to...
# 6   https://www.redbus.in/bus-tickets/kannur-to-ba...
# 7   https://www.redbus.in/bus-tickets/kozhikode-to...
# 8   https://www.redbus.in/bus-tickets/mysore-to-ko...
# 9   https://www.redbus.in/bus-tickets/bangalore-to...
# 10  https://www.redbus.in/bus-tickets/kalpetta-to-...
# 11  https://www.redbus.in/bus-tickets/thiruvananth...
# 12  https://www.redbus.in/bus-tickets/kozhikode-to...
# 13  https://www.redbus.in/bus-tickets/kozhikode-to...
# 14  https://www.redbus.in/bus-tickets/kottayam-to-...

# %%
    from selenium import webdriver
    from selenium.webdriver import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.common.exceptions import TimeoutException, NoSuchElementException
    import time
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    driver_k=webdriver.Chrome()
    Bus_names_k = []
    Bus_types_k = []
    Start_Time_k = []
    End_Time_k = []
    Ratings_k = []
    Total_Duration_k = []
    Prices_k =[]
    Seats_Available_k = []
    Route_names = []
    Route_links = []

    for i,r in KX.iterrows():
        link=r["Route_link"]
        routes=r["Route_name"]

        driver_k.get(link)
        time.sleep(2)

        elements=driver_k.find_elements(By.XPATH,f"//a[contains(@href, '{link}')]")
        for element in elements:
            element.click()
            time.sleep(2)

        try:
            clicks = driver_k.find_element(By.XPATH,"//div[@class='button']")
            clicks.click()
        except:
            continue
        time.sleep(2)

        scrolling=True
        while scrolling:
            old_page_source= driver_k.page_source

            ActionChains(driver_k).send_keys(Keys.PAGE_DOWN).perform()

            time.sleep(5)

            new_page_source= driver_k.page_source

            if new_page_source == old_page_source:
                scrolling = False


        bus_name = driver_k.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")
        bus_type = driver_k.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")
        start_time = driver_k.find_elements(By.XPATH,"//div[@class='dp-time f-19 d-color f-bold']")
        end_time = driver_k.find_elements(By.XPATH,"//div[@class='bp-time f-19 d-color disp-Inline']")
        total_duration = driver_k.find_elements(By.XPATH,"//div[@class='dur l-color lh-24']")
        try:
            rating = driver_k.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
        except:
            continue
        price = driver_k.find_elements(By.XPATH,'//div[@class="fare d-block"]')
        seats = driver_k.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")


        for bus in bus_name:
            Bus_names_k.append(bus.text)
            Route_links.append(link)
            Route_names.append(routes)
        for bus_type_elem in bus_type:
            Bus_types_k.append(bus_type_elem.text)
        for start_time_elem in start_time:
            Start_Time_k.append(start_time_elem.text)
        for end_time_elem in end_time:
            End_Time_k.append(end_time_elem.text)
        for total_duration_elem in total_duration:
            Total_Duration_k.append(total_duration_elem.text)
        for ratings in rating:
            Ratings_k.append(ratings.text)
        for price_elem in price:
            Prices_k.append(price_elem.text)
        for seats_elem in seats:
            Seats_Available_k.append(seats_elem.text)

 
    print("Successfully Completed")
# Out:
# Successfully Completed

# %%
    import pandas as pd
    data= {
        'Bus_name': Bus_names_k,
        'Bus_type': Bus_types_k,
        'Start_time': Start_Time_k,
        'End_time': End_Time_k,
        'Total_duration':Total_Duration_k,
        'Price': Prices_k,
        "Seats_Available":Seats_Available_k,
        "Ratings":Ratings_k,
        'Route_link': Route_links,
        'Route_name': Route_names
    }

    df_buses_1 = pd.DataFrame(data)
    path="df_buses_1.csv"
    df=df_buses_1.to_csv(path,index=False)

# %%
df_buses_1
# Out:
#                   Bus_name                                          Bus_type  \
# 0      KSRTC (Kerala) - 51                 Swift Deluxe Non AC Air Bus (2+2)
# 1     KSRTC (Kerala) - 789                    Super Fast Non AC Seater (2+3)
# 2    KSRTC (Kerala) - 1585         Super Express Non AC Seater Air Bus (2+2)
# 3    KSRTC (Kerala) - 1586         Super Express Non AC Seater Air Bus (2+2)
# 4    KSRTC (Kerala) - 2133                 Swift Deluxe Non AC Air Bus (2+2)
# ..                     ...                                               ...
# 255        Madhavi Travels                                 A/C Sleeper (2+1)
# 256        Madhavi Travels  Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)
# 257          Sonia Travels                          A/C Seater/Sleeper (2+1)
# 258             A1 Travels                        A/C Seater / Sleeper (2+1)
# 259        EMERALD TRAVELS                Bharat Benz A/C Semi Sleeper (2+2)
#
#     Start_time End_time Total_duration    Price     Seats_Available  Ratings  \
# 0        19:00    04:30        09h 30m  INR 640   8 Seats available  4.1\n47
# 1        20:00    03:45        07h 45m  INR 473   4 Seats available  3.9\n79
# 2        20:40    06:10        09h 30m  INR 640  19 Seats available  3.4\n56
# 3        21:30    06:55        09h 25m  INR 640  15 Seats available  3.7\n34
# 4        22:10    07:35        09h 25m  INR 640  14 Seats available  4.1\n20
# ..         ...      ...            ...      ...                 ...      ...
# 255      19:00    03:00        08h 00m  INR 999  11 Seats available   5.0\n2
# 256      23:59    04:30        04h 31m      854  26 Seats available   4.7\n2
# 257      19:10    02:29        07h 19m  INR 750  23 Seats available   3.0\n1
# 258      23:59    07:00        07h 01m  INR 700  29 Seats available  2.5\n19
# 259      23:00    04:30        05h 30m  INR 700  33 Seats available  2.3\n12
#
#                                             Route_link              Route_name
# 0    https://www.redbus.in/bus-tickets/bangalore-to...  Bangalore to Kozhikode
# 1    https://www.redbus.in/bus-tickets/bangalore-to...  Bangalore to Kozhikode
# 2    https://www.redbus.in/bus-tickets/bangalore-to...  Bangalore to Kozhikode
# 3    https://www.redbus.in/bus-tickets/bangalore-to...  Bangalore to Kozhikode
# 4    https://www.redbus.in/bus-tickets/bangalore-to...  Bangalore to Kozhikode
# ..                                                 ...                     ...
# 255  https://www.redbus.in/bus-tickets/kottayam-to-...   Kottayam to Kozhikode
# 256  https://www.redbus.in/bus-tickets/kottayam-to-...   Kottayam to Kozhikode
# 257  https://www.redbus.in/bus-tickets/kottayam-to-...   Kottayam to Kozhikode
# 258  https://www.redbus.in/bus-tickets/kottayam-to-...   Kottayam to Kozhikode
# 259  https://www.redbus.in/bus-tickets/kottayam-to-...   Kottayam to Kozhikode
#
# [260 rows x 10 columns]

# %%
                              #ANDHRA BUS DETAILS

import pandas as pd
AX=pd.read_csv("dfA.csv")
AX
# Out:
#                                  Route_name  \
# 0                   Hyderabad to Vijayawada
# 1                   Vijayawada to Hyderabad
# 2                       Hyderabad to Ongole
# 3                 Kakinada to Visakhapatnam
# 4                     Bangalore to Tirupati
# 5                       Bangalore to Kadapa
# 6                       Ongole to Hyderabad
# 7                       Kadapa to Bangalore
# 8    Chittoor (Andhra Pradesh) to Bangalore
# 9                 Visakhapatnam to Kakinada
# 10  Bangalore to Anantapur (andhra pradesh)
# 11   Bangalore to Chittoor (Andhra Pradesh)
# 12  Anantapur (andhra pradesh) to Bangalore
# 13                     Hyderabad to Kurnool
# 14                    Tirupati to Bangalore
# 15                Narasaraopet to Hyderabad
# 16                   Vinukonda to Hyderabad
# 17                   Hyderabad to Vinukonda
# 18              Visakhapatnam to Vijayawada
# 19                   Bangalore to Rayachoti
# 20     Hyderabad to Guntur (Andhra Pradesh)
# 21     Guntur (Andhra Pradesh) to Hyderabad
# 22                       Hyderabad to Eluru
# 23                       Eluru to Hyderabad
# 24                      Bangalore to Kadiri
# 25                 Madanapalli to Bangalore
# 26                 Bangalore to Madanapalli
# 27   Macherla (andhra pradesh) to Hyderabad
# 28             Rajahmundry to Visakhapatnam
# 29                     Nandyal to Hyderabad
# 30                   Rayachoti to Bangalore
# 31                     Kurnool to Hyderabad
# 32                      Kadiri to Bangalore
# 33             Visakhapatnam to Rajahmundry
# 34                     Hyderabad to Addanki
# 35  Hyderabad to Anantapur (andhra pradesh)
# 36                  Hyderabad to Markapuram
# 37                Rajahmundry to Vijayawada
# 38                      Tirupati to Chennai
# 39              Vijayawada to Visakhapatnam
# 40   Hyderabad to Macherla (andhra pradesh)
# 41                 Hyderabad to Rajahmundry
# 42              Chilakaluripet to Hyderabad
# 43                 Rajahmundry to Hyderabad
# 44                     Kurnool to Bangalore
# 45                     Hyderabad to Nandyal
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/hyderabad-to...
# 1   https://www.redbus.in/bus-tickets/vijayawada-t...
# 2   https://www.redbus.in/bus-tickets/hyderabad-to...
# 3   https://www.redbus.in/bus-tickets/kakinada-to-...
# 4   https://www.redbus.in/bus-tickets/bangalore-to...
# 5   https://www.redbus.in/bus-tickets/bangalore-to...
# 6   https://www.redbus.in/bus-tickets/ongole-to-hy...
# 7   https://www.redbus.in/bus-tickets/kadapa-to-ba...
# 8   https://www.redbus.in/bus-tickets/chittoor-and...
# 9   https://www.redbus.in/bus-tickets/visakhapatna...
# 10  https://www.redbus.in/bus-tickets/bangalore-to...
# 11  https://www.redbus.in/bus-tickets/bangalore-to...
# 12  https://www.redbus.in/bus-tickets/ananthapur-t...
# 13  https://www.redbus.in/bus-tickets/hyderabad-to...
# 14  https://www.redbus.in/bus-tickets/tirupathi-to...
# 15  https://www.redbus.in/bus-tickets/narsaraopet-...
# 16  https://www.redbus.in/bus-tickets/vinukonda-to...
# 17  https://www.redbus.in/bus-tickets/hyderabad-to...
# 18  https://www.redbus.in/bus-tickets/visakhapatna...
# 19  https://www.redbus.in/bus-tickets/bangalore-to...
# 20  https://www.redbus.in/bus-tickets/hyderabad-to...
# 21  https://www.redbus.in/bus-tickets/guntur-to-hy...
# 22  https://www.redbus.in/bus-tickets/hyderabad-to...
# 23  https://www.redbus.in/bus-tickets/eluru-to-hyd...
# 24  https://www.redbus.in/bus-tickets/bangalore-to...
# 25  https://www.redbus.in/bus-tickets/madanapalli-...
# 26  https://www.redbus.in/bus-tickets/bangalore-to...
# 27  https://www.redbus.in/bus-tickets/macherla-to-...
# 28  https://www.redbus.in/bus-tickets/rajahmundry-...
# 29  https://www.redbus.in/bus-tickets/nandyala-to-...
# 30  https://www.redbus.in/bus-tickets/rayachoti-to...
# 31  https://www.redbus.in/bus-tickets/kurnool-to-h...
# 32  https://www.redbus.in/bus-tickets/kadiri-to-ba...
# 33  https://www.redbus.in/bus-tickets/visakhapatna...
# 34  https://www.redbus.in/bus-tickets/hyderabad-to...
# 35  https://www.redbus.in/bus-tickets/hyderabad-to...
# 36  https://www.redbus.in/bus-tickets/hyderabad-to...
# 37  https://www.redbus.in/bus-tickets/rajahmundry-...
# 38  https://www.redbus.in/bus-tickets/tirupathi-to...
# 39  https://www.redbus.in/bus-tickets/vijayawada-t...
# 40  https://www.redbus.in/bus-tickets/hyderabad-to...
# 41  https://www.redbus.in/bus-tickets/hyderabad-to...
# 42  https://www.redbus.in/bus-tickets/chilakalurip...
# 43  https://www.redbus.in/bus-tickets/rajahmundry-...
# 44  https://www.redbus.in/bus-tickets/kurnool-to-b...
# 45  https://www.redbus.in/bus-tickets/hyderabad-to...

# %%
    from selenium import webdriver
    from selenium.webdriver import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.common.exceptions import TimeoutException, NoSuchElementException
    import time
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    driver_A=webdriver.Chrome()
    Bus_names_A = []
    Bus_types_A = []
    Start_Time_A = []
    End_Time_A = []
    Ratings_A= []
    Total_Duration_A= []
    Prices_A =[]
    Seats_Available_A = []
    Route_names = []
    Route_links = []

    for i,r in AX.iterrows():
        link=r["Route_link"]
        routes=r["Route_name"]

        driver_A.get(link)
        time.sleep(2)

        elements=driver_A.find_elements(By.XPATH,f"//a[contains(@href, '{link}')]")
        for element in elements:
            element.click()
            time.sleep(2)

        try:
            clicks = driver_A.find_element(By.XPATH,"//div[@class='button']")
            clicks.click()
        except:
            continue
        time.sleep(2)

        scrolling=True
        while scrolling:
            old_page_source= driver_A.page_source

            ActionChains(driver_A).send_keys(Keys.PAGE_DOWN).perform()

            time.sleep(5)

            new_page_source= driver_A.page_source

            if new_page_source == old_page_source:
                scrolling = False


        bus_name = driver_A.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")
        bus_type = driver_A.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")
        start_time = driver_A.find_elements(By.XPATH,"//div[@class='dp-time f-19 d-color f-bold']")
        end_time = driver_A.find_elements(By.XPATH,"//div[@class='bp-time f-19 d-color disp-Inline']")
        total_duration = driver_A.find_elements(By.XPATH,"//div[@class='dur l-color lh-24']")
        try:
            rating = driver_A.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
        except:
            continue
        price = driver_A.find_elements(By.XPATH,'//div[@class="fare d-block"]')
        seats = driver_A.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")


        for bus in bus_name:
            Bus_names_A.append(bus.text)
            Route_links.append(link)
            Route_names.append(routes)
        for bus_type_elem in bus_type:
            Bus_types_A.append(bus_type_elem.text)
        for start_time_elem in start_time:
            Start_Time_A.append(start_time_elem.text)
        for end_time_elem in end_time:
            End_Time_A.append(end_time_elem.text)
        for total_duration_elem in total_duration:
            Total_Duration_A.append(total_duration_elem.text)
        for ratings in rating:
            Ratings_A.append(ratings.text)
        for price_elem in price:
            Prices_A.append(price_elem.text)
        for seats_elem in seats:
            Seats_Available_A.append(seats_elem.text)

 
    print("Successfully Completed")
# Out:
# Successfully Completed

# %%
    import pandas as pd
    data= {
        'Bus_name': Bus_names_A,
        'Bus_type': Bus_types_A,
        'Start_time': Start_Time_A,
        'End_time': End_Time_A,
        'Total_duration':Total_Duration_A,
        'Price': Prices_A,
        "Seats_Available":Seats_Available_A,
        "Ratings":Ratings_A,
        'Route_link': Route_links,
        'Route_name': Route_names
    }

    df_buses_2 = pd.DataFrame(data)
    path="df_buses_2.csv"
    df=df_buses_2.to_csv(path,index=False)

# %%
df_buses_2
# Out:
#                                 Bus_name                            Bus_type  \
# 0    Sri Vengamamba Bus Transport (SVBT)          A/C Seater / Sleeper (2+1)
# 1                       V Kaveri Travels  Scania AC Multi Axle Sleeper (2+1)
# 2             Kamakshi Tours And Travels      Non A/C Seater / Sleeper (2+1)
# 3                         Chandu Travels                   A/C Sleeper (2+1)
# 4                       V Kaveri Travels  Volvo Multi-Axle A/C Sleeper (2+1)
# ..                                   ...                                 ...
# 583                         Indu Travels      Non A/C Seater / Sleeper (2+1)
# 584                         Indu Travels      Non A/C Seater / Sleeper (2+1)
# 585                          BRS Travels         NON AC Seater / Sleeper 2+1
# 586                          BRS Travels                   A/C Sleeper (2+1)
# 587                            INDHU BUS      Non A/C Seater / Sleeper (2+1)
#
#     Start_time End_time Total_duration     Price     Seats_Available  \
# 0        21:40    06:15        08h 35m   INR 785  12 Seats available
# 1        21:30    05:45        08h 15m  INR 1290  19 Seats available
# 2        21:30    06:00        08h 30m   INR 600  16 Seats available
# 3        22:00    05:45        07h 45m       941  13 Seats available
# 4        21:30    05:30        08h 00m  INR 1050  10 Seats available
# ..         ...      ...            ...       ...                 ...
# 583      22:00    04:30        06h 30m   INR 550  31 Seats available
# 584      21:45    04:20        06h 35m   INR 550  26 Seats available
# 585      22:10    05:00        06h 50m   INR 800  35 Seats available
# 586      22:15    05:30        07h 15m  INR 1050  16 Seats available
# 587      21:30    04:10        06h 40m   INR 600  26 Seats available
#
#       Ratings                                         Route_link  \
# 0    4.4\n292  https://www.redbus.in/bus-tickets/hyderabad-to...
# 1    4.3\n259  https://www.redbus.in/bus-tickets/hyderabad-to...
# 2    4.3\n223  https://www.redbus.in/bus-tickets/hyderabad-to...
# 3    4.1\n154  https://www.redbus.in/bus-tickets/hyderabad-to...
# 4    3.9\n139  https://www.redbus.in/bus-tickets/hyderabad-to...
# ..        ...                                                ...
# 583  4.4\n156  https://www.redbus.in/bus-tickets/hyderabad-to...
# 584  4.2\n233  https://www.redbus.in/bus-tickets/hyderabad-to...
# 585  4.0\n353  https://www.redbus.in/bus-tickets/hyderabad-to...
# 586  3.9\n342  https://www.redbus.in/bus-tickets/hyderabad-to...
# 587  4.0\n117  https://www.redbus.in/bus-tickets/hyderabad-to...
#
#                Route_name
# 0     Hyderabad to Ongole
# 1     Hyderabad to Ongole
# 2     Hyderabad to Ongole
# 3     Hyderabad to Ongole
# 4     Hyderabad to Ongole
# ..                    ...
# 583  Hyderabad to Nandyal
# 584  Hyderabad to Nandyal
# 585  Hyderabad to Nandyal
# 586  Hyderabad to Nandyal
# 587  Hyderabad to Nandyal
#
# [588 rows x 10 columns]

# %%
                                              #TELUNGANA BUS DETAILS

import pandas as pd
TX=pd.read_csv("dfT.csv")
TX
# Out:
#                               Route_name  \
# 0                Hyderabad to Vijayawada
# 1                   Khammam to Hyderabad
# 2                   Hyderabad to Khammam
# 3                 Hyderabad to Srisailam
# 4                Karimnagar to Hyderabad
# 5                Hyderabad to Karimnagar
# 6                Hyderabad to Mancherial
# 7                    Hyderabad to Nirmal
# 8                  Hyderabad to Adilabad
# 9                    Hyderabad to Ongole
# 10               Kothagudem to Hyderabad
# 11  Guntur (Andhra Pradesh) to Hyderabad
# 12  Hyderabad to Guntur (Andhra Pradesh)
# 13            Godavarikhani to Hyderabad
# 14               Hyderabad to Kothagudem
# 15               Hyderabad to Sathupally
# 16                 Hyderabad to Warangal
# 17                    Kodad to Hyderabad
# 18                 Jagityal to Hyderabad
# 19             Hyderabad to Bhadrachalam
# 20                 Hyderabad to Tirupati
# 21            Hyderabad to Godavarikhani
# 22                   Hyderabad to Armoor
# 23                  Hyderabad to Nandyal
# 24                    Hyderabad to Kodad
# 25                  Hyderabad to Addanki
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/hyderabad-to...
# 1   https://www.redbus.in/bus-tickets/khammam-to-h...
# 2   https://www.redbus.in/bus-tickets/hyderabad-to...
# 3   https://www.redbus.in/bus-tickets/hyderabad-to...
# 4   https://www.redbus.in/bus-tickets/karimnagar-t...
# 5   https://www.redbus.in/bus-tickets/hyderabad-to...
# 6   https://www.redbus.in/bus-tickets/hyderabad-to...
# 7   https://www.redbus.in/bus-tickets/hyderabad-to...
# 8   https://www.redbus.in/bus-tickets/hyderabad-to...
# 9   https://www.redbus.in/bus-tickets/hyderabad-to...
# 10  https://www.redbus.in/bus-tickets/kothagudem-t...
# 11  https://www.redbus.in/bus-tickets/guntur-to-hy...
# 12  https://www.redbus.in/bus-tickets/hyderabad-to...
# 13  https://www.redbus.in/bus-tickets/godavarikhan...
# 14  https://www.redbus.in/bus-tickets/hyderabad-to...
# 15  https://www.redbus.in/bus-tickets/hyderabad-to...
# 16  https://www.redbus.in/bus-tickets/hyderabad-to...
# 17  https://www.redbus.in/bus-tickets/kodad-to-hyd...
# 18  https://www.redbus.in/bus-tickets/jagityal-to-...
# 19  https://www.redbus.in/bus-tickets/hyderabad-to...
# 20  https://www.redbus.in/bus-tickets/hyderabad-to...
# 21  https://www.redbus.in/bus-tickets/hyderabad-to...
# 22  https://www.redbus.in/bus-tickets/hyderabad-to...
# 23  https://www.redbus.in/bus-tickets/hyderabad-to...
# 24  https://www.redbus.in/bus-tickets/hyderabad-to...
# 25  https://www.redbus.in/bus-tickets/hyderabad-to...

# %%
    from selenium import webdriver
    from selenium.webdriver import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.common.exceptions import TimeoutException, NoSuchElementException
    import time
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    driver_T=webdriver.Chrome()
    Bus_names_T = []
    Bus_types_T = []
    Start_Time_T = []
    End_Time_T = []
    Ratings_T= []
    Total_Duration_T= []
    Prices_T =[]
    Seats_Available_T = []
    Route_names = []
    Route_links = []

    for i,r in TX.iterrows():
        link=r["Route_link"]
        routes=r["Route_name"]

        driver_T.get(link)
        time.sleep(2)

        elements=driver_T.find_elements(By.XPATH,f"//a[contains(@href, '{link}')]")
        for element in elements:
            element.click()
            time.sleep(2)

        try:
            clicks = driver_T.find_element(By.XPATH,"//div[@class='button']")
            clicks.click()
        except:
            continue
        time.sleep(2)

        scrolling=True
        while scrolling:
            old_page_source= driver_T.page_source

            ActionChains(driver_T).send_keys(Keys.PAGE_DOWN).perform()

            time.sleep(5)

            new_page_source= driver_T.page_source

            if new_page_source == old_page_source:
                scrolling = False


        bus_name = driver_T.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")
        bus_type = driver_T.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")
        start_time = driver_T.find_elements(By.XPATH,"//div[@class='dp-time f-19 d-color f-bold']")
        end_time = driver_T.find_elements(By.XPATH,"//div[@class='bp-time f-19 d-color disp-Inline']")
        total_duration = driver_T.find_elements(By.XPATH,"//div[@class='dur l-color lh-24']")
        try:
            rating = driver_T.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
        except:
            continue
        price = driver_T.find_elements(By.XPATH,'//div[@class="fare d-block"]')
        seats = driver_T.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")


        for bus in bus_name:
            Bus_names_T.append(bus.text)
            Route_links.append(link)
            Route_names.append(routes)
        for bus_type_elem in bus_type:
            Bus_types_T.append(bus_type_elem.text)
        for start_time_elem in start_time:
            Start_Time_T.append(start_time_elem.text)
        for end_time_elem in end_time:
            End_Time_T.append(end_time_elem.text)
        for total_duration_elem in total_duration:
            Total_Duration_T.append(total_duration_elem.text)
        for ratings in rating:
            Ratings_T.append(ratings.text)
        for price_elem in price:
            Prices_T.append(price_elem.text)
        for seats_elem in seats:
            Seats_Available_T.append(seats_elem.text)

 
    print("Successfully Completed")
# Out:
# Successfully Completed

# %%
    import pandas as pd
    data= {
        'Bus_name': Bus_names_T,
        'Bus_type': Bus_types_T,
        'Start_time': Start_Time_T,
        'End_time': End_Time_T,
        'Total_duration':Total_Duration_T,
        'Price': Prices_T,
        "Seats_Available":Seats_Available_T,
        "Ratings":Ratings_T,
        'Route_link': Route_links,
        'Route_name': Route_names
    }

    df_buses_3 = pd.DataFrame(data)
    path="df_buses_3.csv"
    df=df_buses_3.to_csv(path,index=False)

# %%
df_buses_3
# Out:
#                      Bus_name                            Bus_type Start_time  \
# 0                    FRESHBUS           Electric A/C Seater (2+2)      23:10
# 1                       NueGo           Electric A/C Seater (2+2)      22:35
# 2           IntrCity SmartBus          A/C Seater / Sleeper (2+1)      23:50
# 3         AdIntrCity SmartBus          A/C Seater / Sleeper (2+1)      23:05
# 4           IntrCity SmartBus  Scania AC Multi Axle Sleeper (2+1)      23:59
# ..                        ...                                 ...        ...
# 343  Orange Tours And Travels  Volvo Multi-Axle Sleeper A/C (2+1)      23:45
# 344      SAI PRASANNA TRAVELS      Non A/C Seater / Sleeper (2+1)      21:40
# 345       Sri Krishna Travels    A/C Semi Sleeper / Sleeper (2+1)      21:45
# 346          V Kaveri Travels                   A/C Sleeper (2+1)      22:00
# 347              Mozo travels                   A/C Sleeper (2+1)      22:00
#
#     End_time Total_duration     Price     Seats_Available   Ratings  \
# 0      05:35        06h 25m       630  28 Seats available  4.6\n494
# 1      05:15        06h 40m       631  11 Seats available  4.6\n285
# 2      05:35        05h 45m   INR 575  26 Seats available  4.4\n955
# 3      06:00        06h 55m   INR 428  31 Seats available  4.4\n563
# 4      06:30        06h 31m   INR 849  23 Seats available  4.5\n476
# ..       ...            ...       ...                 ...       ...
# 343    06:15        06h 30m  INR 1000  20 Seats available   3.5\n35
# 344    04:50        07h 10m   INR 555  19 Seats available   3.7\n26
# 345    04:30        06h 45m   INR 800  23 Seats available   3.2\n38
# 346    05:45        07h 45m  INR 1000  25 Seats available   4.3\n13
# 347    04:00        06h 00m   INR 950   7 Seats available    4.9\n7
#
#                                             Route_link  \
# 0    https://www.redbus.in/bus-tickets/hyderabad-to...
# 1    https://www.redbus.in/bus-tickets/hyderabad-to...
# 2    https://www.redbus.in/bus-tickets/hyderabad-to...
# 3    https://www.redbus.in/bus-tickets/hyderabad-to...
# 4    https://www.redbus.in/bus-tickets/hyderabad-to...
# ..                                                 ...
# 343  https://www.redbus.in/bus-tickets/hyderabad-to...
# 344  https://www.redbus.in/bus-tickets/hyderabad-to...
# 345  https://www.redbus.in/bus-tickets/hyderabad-to...
# 346  https://www.redbus.in/bus-tickets/hyderabad-to...
# 347  https://www.redbus.in/bus-tickets/hyderabad-to...
#
#                   Route_name
# 0    Hyderabad to Vijayawada
# 1    Hyderabad to Vijayawada
# 2    Hyderabad to Vijayawada
# 3    Hyderabad to Vijayawada
# 4    Hyderabad to Vijayawada
# ..                       ...
# 343     Hyderabad to Addanki
# 344     Hyderabad to Addanki
# 345     Hyderabad to Addanki
# 346     Hyderabad to Addanki
# 347     Hyderabad to Addanki
#
# [348 rows x 10 columns]

# %%
                                  #SOUTH BENGAL BUS DETAILS

import pandas as pd
SBX=pd.read_csv("dfSB.csv")
SBX
# Out:
#                                            Route_name  \
# 0                                Durgapur to Calcutta
# 1                                  Kolkata to Burdwan
# 2                                  Haldia to Calcutta
# 3                                   Kolkata to Haldia
# 4                   Kolkata to Durgapur (West Bengal)
# 5                   Kolkata to Arambagh (West Bengal)
# 6                                Midnapore to Kolkata
# 7                                    Kolkata to Digha
# 8                                   Digha to Calcutta
# 9                                  Kolkata to Bankura
# 10                               Kolkata to Midnapore
# 11                   Kolkata to Asansol (West Bengal)
# 12                                Kolkata to Nimtouri
# 13                                Jhargram to Kolkata
# 14                         Kolkata to Contai (Kanthi)
# 15                                Kolkata to Kolaghat
# 16                Kolkata to Nandakumar (west bengal)
# 17                   Kolkata to Mecheda (West Bengal)
# 18                    Digha to Durgapur (West Bengal)
# 19                 Midnapore to Barasat (West Bengal)
# 20                    Durgapur (West Bengal) to Digha
# 21                 Kolkata to Chandipur (West Bengal)
# 22                 Barasat (West Bengal) to Midnapore
# 23                                   Kolkata to Debra
# 24                  Kirnahar (West Bengal) to Kolkata
# 25                                Kolkata to Panskura
# 26                                   Kolkata to Heria
# 27                     Digha to Barasat (West Bengal)
# 28                              Illambazar to Kolkata
# 29                                    Kolkata to Suri
# 30  Berhampore (West Bengal) to Durgapur (West Ben...
# 31                  Purulia to Durgapur (West Bengal)
# 32  Durgapur (West Bengal) to Berhampore (West Ben...
# 33                              Kolkata to Futishanko
# 34                  Kolkata to Kirnahar (West Bengal)
# 35    Durgapur (West Bengal) to Barasat (West Bengal)
# 36                  Kolkata to Ramnagar (West Bengal)
# 37                  Durgapur (West Bengal) to Purulia
# 38                  Durgapur (West Bengal) to Bankura
# 39                                  Kolkata to Ashari
# 40                     Barasat (West Bengal) to Digha
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/durgapur-to-...
# 1   https://www.redbus.in/bus-tickets/kolkata-to-b...
# 2   https://www.redbus.in/bus-tickets/haldia-to-ko...
# 3   https://www.redbus.in/bus-tickets/kolkata-to-h...
# 4   https://www.redbus.in/bus-tickets/kolkata-to-d...
# 5   https://www.redbus.in/bus-tickets/kolkata-to-a...
# 6   https://www.redbus.in/bus-tickets/midnapore-to...
# 7   https://www.redbus.in/bus-tickets/kolkata-to-d...
# 8   https://www.redbus.in/bus-tickets/digha-to-kol...
# 9   https://www.redbus.in/bus-tickets/kolkata-to-b...
# 10  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 11  https://www.redbus.in/bus-tickets/kolkata-to-a...
# 12  https://www.redbus.in/bus-tickets/kolkata-to-n...
# 13  https://www.redbus.in/bus-tickets/jhargram-to-...
# 14  https://www.redbus.in/bus-tickets/kolkata-to-c...
# 15  https://www.redbus.in/bus-tickets/kolkata-to-k...
# 16  https://www.redbus.in/bus-tickets/kolkata-to-n...
# 17  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 18  https://www.redbus.in/bus-tickets/digha-to-dur...
# 19  https://www.redbus.in/bus-tickets/midnapore-to...
# 20  https://www.redbus.in/bus-tickets/durgapur-to-...
# 21  https://www.redbus.in/bus-tickets/kolkata-to-c...
# 22  https://www.redbus.in/bus-tickets/barasat-west...
# 23  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 24  https://www.redbus.in/bus-tickets/kirnahar-wes...
# 25  https://www.redbus.in/bus-tickets/kolkata-to-p...
# 26  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 27  https://www.redbus.in/bus-tickets/digha-to-bar...
# 28  https://www.redbus.in/bus-tickets/illambazar-t...
# 29  https://www.redbus.in/bus-tickets/kolkata-to-suri
# 30  https://www.redbus.in/bus-tickets/berhampore-t...
# 31  https://www.redbus.in/bus-tickets/purulia-to-d...
# 32  https://www.redbus.in/bus-tickets/durgapur-to-...
# 33  https://www.redbus.in/bus-tickets/kolkata-to-f...
# 34  https://www.redbus.in/bus-tickets/kolkata-to-k...
# 35  https://www.redbus.in/bus-tickets/durgapur-to-...
# 36  https://www.redbus.in/bus-tickets/kolkata-to-r...
# 37  https://www.redbus.in/bus-tickets/durgapur-to-...
# 38  https://www.redbus.in/bus-tickets/durgapur-to-...
# 39  https://www.redbus.in/bus-tickets/kolkata-to-a...
# 40  https://www.redbus.in/bus-tickets/barasat-west...

# %%
    from selenium import webdriver
    from selenium.webdriver import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.common.exceptions import TimeoutException, NoSuchElementException
    import time
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    driver_SB=webdriver.Chrome()
    Bus_names_SB = []
    Bus_types_SB = []
    Start_Time_SB = []
    End_Time_SB = []
    Ratings_SB= []
    Total_Duration_SB= []
    Prices_SB =[]
    Seats_Available_SB = []
    Route_names = []
    Route_links = []

    for i,r in SBX.iterrows():
        link=r["Route_link"]
        routes=r["Route_name"]

        driver_SB.get(link)
        time.sleep(2)

        elements=driver_SB.find_elements(By.XPATH,f"//a[contains(@href, '{link}')]")
        for element in elements:
            element.click()
            time.sleep(2)

        try:
            clicks = driver_SB.find_element(By.XPATH,"//div[@class='button']")
            clicks.click()
        except:
            continue
        time.sleep(2)

        scrolling=True
        while scrolling:
            old_page_source= driver_SB.page_source

            ActionChains(driver_SB).send_keys(Keys.PAGE_DOWN).perform()

            time.sleep(5)

            new_page_source= driver_SB.page_source

            if new_page_source == old_page_source:
                scrolling = False


        bus_name = driver_SB.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")
        bus_type = driver_SB.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")
        start_time = driver_SB.find_elements(By.XPATH,"//div[@class='dp-time f-19 d-color f-bold']")
        end_time = driver_SB.find_elements(By.XPATH,"//div[@class='bp-time f-19 d-color disp-Inline']")
        total_duration = driver_SB.find_elements(By.XPATH,"//div[@class='dur l-color lh-24']")
        try:
            rating = driver_SB.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
        except:
            continue
        price = driver_SB.find_elements(By.XPATH,'//div[@class="fare d-block"]')
        seats = driver_SB.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")


        for bus in bus_name:
            Bus_names_SB.append(bus.text)
            Route_links.append(link)
            Route_names.append(routes)
        for bus_type_elem in bus_type:
            Bus_types_SB.append(bus_type_elem.text)
        for start_time_elem in start_time:
            Start_Time_SB.append(start_time_elem.text)
        for end_time_elem in end_time:
            End_Time_SB.append(end_time_elem.text)
        for total_duration_elem in total_duration:
            Total_Duration_SB.append(total_duration_elem.text)
        for ratings in rating:
            Ratings_SB.append(ratings.text)
        for price_elem in price:
            Prices_SB.append(price_elem.text)
        for seats_elem in seats:
            Seats_Available_SB.append(seats_elem.text)

 
    print("Successfully Completed")
# Out:
# Successfully Completed

# %%
    import pandas as pd
    data= {
        'Bus_name': Bus_names_SB,
        'Bus_type': Bus_types_SB,
        'Start_time': Start_Time_SB,
        'End_time': End_Time_SB,
        'Total_duration':Total_Duration_SB,
        'Price': Prices_SB,
        "Seats_Available":Seats_Available_SB,
        "Ratings":Ratings_SB,
        'Route_link': Route_links,
        'Route_name': Route_names
    }

    df_buses_4 = pd.DataFrame(data)
    path="df_buses_4.csv"
    df=df_buses_4.to_csv(path,index=False)

# %%
df_buses_4
# Out:
#                                               Bus_name  \
# 0    SBSTC-BANKURA - KARUNAMOYEE - 13:00 (BNK DEPOT...
# 1    SBSTC-DURGAPUR - KARUNAMOYEE - A/C - 15:10 (DG...
# 2    SBSTC-ASANSOL - KOLKATA - 14:35 (HOWRAH DEPOT)...
# 3    SBSTC-BANKURA - KARUNAMOYEE - 14:15 (BNK DEPOT...
# 4    SBSTC-ASANSOL - KOLKATA - 15:05 (HWH DEPOT) - 210
# ..                                                 ...
# 164  SBSTC-KOLKATA - PURULIA - VIA - BANKURA - 13:0...
# 165  SBSTC-DURGAPUR - MANBAZAR - 16:10 (MAN BZR) - ...
# 166  SBSTC-KARUNAMOYEE - BANKURA - A/C - 15:15 (BNK...
# 167                          Dolphin tours and travels
# 168                               Sri Balaji Parivahan
#
#                        Bus_type Start_time End_time Total_duration    Price  \
# 0           Non AC Seater (2+3)      14:55    18:55        04h 00m  INR 155
# 1               AC Seater (2+2)      15:10    19:10        04h 00m  INR 300
# 2           Non AC Seater (2+3)      15:45    19:15        03h 30m  INR 150
# 3           Non AC Seater (2+3)      16:00    20:00        04h 00m  INR 155
# 4           Non AC Seater (2+3)      16:15    19:45        03h 30m  INR 150
# ..                          ...        ...      ...            ...      ...
# 164         Non AC Seater (2+3)      16:00    17:00        01h 00m   INR 53
# 165         Non AC Seater (2+3)      16:10    17:10        01h 00m   INR 53
# 166             AC Seater (2+2)      19:30    00:00        04h 30m   INR 70
# 167  A/C Seater / Sleeper (2+2)      17:45    19:00        01h 15m  INR 896
# 168         Non AC Seater (2+3)      15:45    17:30        01h 45m  INR 110
#
#         Seats_Available   Ratings  \
# 0    41 Seats available   3.5\n63
# 1    26 Seats available  3.0\n138
# 2    52 Seats available   2.3\n22
# 3    38 Seats available   3.3\n64
# 4    44 Seats available   3.1\n42
# ..                  ...       ...
# 164  32 Seats available    1.0\n2
# 165  52 Seats available       2.9
# 166  34 Seats available    4.2\n3
# 167  22 Seats available       3.7
# 168  10 Seats available       2.7
#
#                                             Route_link  \
# 0    https://www.redbus.in/bus-tickets/durgapur-to-...
# 1    https://www.redbus.in/bus-tickets/durgapur-to-...
# 2    https://www.redbus.in/bus-tickets/durgapur-to-...
# 3    https://www.redbus.in/bus-tickets/durgapur-to-...
# 4    https://www.redbus.in/bus-tickets/durgapur-to-...
# ..                                                 ...
# 164  https://www.redbus.in/bus-tickets/durgapur-to-...
# 165  https://www.redbus.in/bus-tickets/durgapur-to-...
# 166  https://www.redbus.in/bus-tickets/durgapur-to-...
# 167  https://www.redbus.in/bus-tickets/durgapur-to-...
# 168  https://www.redbus.in/bus-tickets/durgapur-to-...
#
#                             Route_name
# 0                 Durgapur to Calcutta
# 1                 Durgapur to Calcutta
# 2                 Durgapur to Calcutta
# 3                 Durgapur to Calcutta
# 4                 Durgapur to Calcutta
# ..                                 ...
# 164  Durgapur (West Bengal) to Bankura
# 165  Durgapur (West Bengal) to Bankura
# 166  Durgapur (West Bengal) to Bankura
# 167  Durgapur (West Bengal) to Bankura
# 168  Durgapur (West Bengal) to Bankura
#
# [169 rows x 10 columns]

# %%
                         #RAJASTHAN BUS DETAILS

import pandas as pd
RX=pd.read_csv("dfR.csv")
RX
# Out:
#                                        Route_name  \
# 0                              Udaipur to Jodhpur
# 1                                Jodhpur to Ajmer
# 2        Beawar (Rajasthan) to Jaipur (Rajasthan)
# 3                     Sikar to Jaipur (Rajasthan)
# 4                   Jaipur (Rajasthan) to Jodhpur
# 5   Aligarh (uttar pradesh) to Jaipur (Rajasthan)
# 6   Jaipur (Rajasthan) to Aligarh (uttar pradesh)
# 7                   Jodhpur to Beawar (Rajasthan)
# 8                    Jaipur (Rajasthan) to Pilani
# 9                Kishangarh to Jaipur (Rajasthan)
# 10                    Pali (Rajasthan) to Udaipur
# 11                    Udaipur to Pali (Rajasthan)
# 12                     Kota(Rajasthan) to Udaipur
# 13                 Jaipur (Rajasthan) to Bhilwara
# 14                               Sikar to Bikaner
# 15                Jaipur (Rajasthan) to Bharatpur
# 16                  Jaipur (Rajasthan) to Mathura
# 17          Jaipur (Rajasthan) to Kota(Rajasthan)
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/udaipur-to-j...
# 1   https://www.redbus.in/bus-tickets/jodhpur-to-a...
# 2   https://www.redbus.in/bus-tickets/beawer-to-ja...
# 3   https://www.redbus.in/bus-tickets/sikar-to-jaipur
# 4   https://www.redbus.in/bus-tickets/jaipur-to-jo...
# 5   https://www.redbus.in/bus-tickets/aligarh-utta...
# 6   https://www.redbus.in/bus-tickets/jaipur-to-al...
# 7   https://www.redbus.in/bus-tickets/jodhpur-to-b...
# 8   https://www.redbus.in/bus-tickets/jaipur-to-pi...
# 9   https://www.redbus.in/bus-tickets/kishangarh-t...
# 10  https://www.redbus.in/bus-tickets/pali-to-udaipur
# 11  https://www.redbus.in/bus-tickets/udaipur-to-p...
# 12  https://www.redbus.in/bus-tickets/kota-rajasth...
# 13  https://www.redbus.in/bus-tickets/jaipur-to-bh...
# 14  https://www.redbus.in/bus-tickets/sikar-to-bik...
# 15  https://www.redbus.in/bus-tickets/jaipur-to-bh...
# 16  https://www.redbus.in/bus-tickets/jaipur-to-ma...
# 17  https://www.redbus.in/bus-tickets/jaipur-to-ko...

# %%
    from selenium import webdriver
    from selenium.webdriver import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.common.exceptions import TimeoutException, NoSuchElementException
    import time
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    driver_R=webdriver.Chrome()
    Bus_names_R = []
    Bus_types_R = []
    Start_Time_R = []
    End_Time_R = []
    Ratings_R= []
    Total_Duration_R= []
    Prices_R =[]
    Seats_Available_R = []
    Route_names = []
    Route_links = []

    for i,r in RX.iterrows():
        link=r["Route_link"]
        routes=r["Route_name"]

        driver_R.get(link)
        time.sleep(2)

        elements=driver_R.find_elements(By.XPATH,f"//a[contains(@href, '{link}')]")
        for element in elements:
            element.click()
            time.sleep(2)

        try:
            clicks = driver_R.find_element(By.XPATH,"//div[@class='button']")
            clicks.click()
        except:
            continue
        time.sleep(2)

        scrolling=True
        while scrolling:
            old_page_source= driver_R.page_source

            ActionChains(driver_R).send_keys(Keys.PAGE_DOWN).perform()

            time.sleep(5)

            new_page_source= driver_R.page_source

            if new_page_source == old_page_source:
                scrolling = False


        bus_name = driver_R.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")
        bus_type = driver_R.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")
        start_time = driver_R.find_elements(By.XPATH,"//div[@class='dp-time f-19 d-color f-bold']")
        end_time = driver_R.find_elements(By.XPATH,"//div[@class='bp-time f-19 d-color disp-Inline']")
        total_duration = driver_R.find_elements(By.XPATH,"//div[@class='dur l-color lh-24']")
        try:
            rating = driver_R.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
        except:
            continue
        price = driver_R.find_elements(By.XPATH,'//div[@class="fare d-block"]')
        seats = driver_R.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")


        for bus in bus_name:
            Bus_names_R.append(bus.text)
            Route_links.append(link)
            Route_names.append(routes)
        for bus_type_elem in bus_type:
            Bus_types_R.append(bus_type_elem.text)
        for start_time_elem in start_time:
            Start_Time_R.append(start_time_elem.text)
        for end_time_elem in end_time:
            End_Time_R.append(end_time_elem.text)
        for total_duration_elem in total_duration:
            Total_Duration_R.append(total_duration_elem.text)
        for ratings in rating:
            Ratings_R.append(ratings.text)
        for price_elem in price:
            Prices_R.append(price_elem.text)
        for seats_elem in seats:
            Seats_Available_R.append(seats_elem.text)

 
    print("Successfully Completed")
# Out:
# Successfully Completed

# %%
    import pandas as pd
    data= {
        'Bus_name': Bus_names_R,
        'Bus_type': Bus_types_R,
        'Start_time': Start_Time_R,
        'End_time': End_Time_R,
        'Total_duration':Total_Duration_R,
        'Price': Prices_R,
        "Seats_Available":Seats_Available_R,
        "Ratings":Ratings_R,
        'Route_link': Route_links,
        'Route_name': Route_names
    }

    df_buses_5 = pd.DataFrame(data)
    path="df_buses_5.csv"
    df=df_buses_5.to_csv(path,index=False)

# %%
df_buses_5
# Out:
#                      Bus_name  \
# 0              RSRTC - 193271
# 1              RSRTC - 189622
# 2    Shree Devnarayan Travels
# 3                 M R Travels
# 4                  Raj Travel
# ..                        ...
# 186              Babu Travels
# 187            Jakhar Travels
# 188     Raj travels Jhunjhunu
# 189            Gajraj Travels
# 190            Ganesh Travels
#
#                                              Bus_type Start_time End_time  \
# 0                           Express Non AC Seater 2+3      19:30    02:00
# 1                           Express Non AC Seater 2+3      22:00    05:00
# 2                        Bharat Benz A/C Seater (2+1)      17:00    21:30
# 3    Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)      17:10    21:55
# 4                                   A/C Sleeper (2+1)      22:30    05:30
# ..                                                ...        ...      ...
# 186                                 A/C Sleeper (2+1)      22:15    04:45
# 187                        A/C Seater / Sleeper (2+1)      19:30    23:55
# 188                        A/C Seater / Sleeper (2+1)      23:30    05:00
# 189                     Bharat Benz A/C Sleeper (2+1)      21:00    02:00
# 190                     NON A/C Seater/ Sleeper (2+1)      20:30    02:15
#
#     Total_duration    Price     Seats_Available   Ratings  \
# 0          06h 30m  INR 294  11 Seats available    4.2\n4
# 1          07h 00m  INR 294  42 Seats available    3.5\n7
# 2          04h 30m  INR 550   4 Seats available  4.5\n288
# 3          04h 45m  INR 485  36 Seats available  4.5\n430
# 4          07h 00m  INR 560  24 Seats available   4.7\n80
# ..             ...      ...                 ...       ...
# 186        06h 30m  INR 250  24 Seats available   3.1\n88
# 187        04h 25m  INR 400  17 Seats available   3.8\n40
# 188        05h 30m      380  18 Seats available   3.0\n54
# 189        05h 00m  INR 810  15 Seats available    5.0\n6
# 190        05h 45m  INR 300  25 Seats available   3.8\n13
#
#                                             Route_link  \
# 0    https://www.redbus.in/bus-tickets/udaipur-to-j...
# 1    https://www.redbus.in/bus-tickets/udaipur-to-j...
# 2    https://www.redbus.in/bus-tickets/udaipur-to-j...
# 3    https://www.redbus.in/bus-tickets/udaipur-to-j...
# 4    https://www.redbus.in/bus-tickets/udaipur-to-j...
# ..                                                 ...
# 186  https://www.redbus.in/bus-tickets/jaipur-to-ko...
# 187  https://www.redbus.in/bus-tickets/jaipur-to-ko...
# 188  https://www.redbus.in/bus-tickets/jaipur-to-ko...
# 189  https://www.redbus.in/bus-tickets/jaipur-to-ko...
# 190  https://www.redbus.in/bus-tickets/jaipur-to-ko...
#
#                                 Route_name
# 0                       Udaipur to Jodhpur
# 1                       Udaipur to Jodhpur
# 2                       Udaipur to Jodhpur
# 3                       Udaipur to Jodhpur
# 4                       Udaipur to Jodhpur
# ..                                     ...
# 186  Jaipur (Rajasthan) to Kota(Rajasthan)
# 187  Jaipur (Rajasthan) to Kota(Rajasthan)
# 188  Jaipur (Rajasthan) to Kota(Rajasthan)
# 189  Jaipur (Rajasthan) to Kota(Rajasthan)
# 190  Jaipur (Rajasthan) to Kota(Rajasthan)
#
# [191 rows x 10 columns]

# %%
                                   #GOA BUS DETAILS

import pandas as pd
GX=pd.read_csv("dfG.csv")
GX
# Out:
#                          Route_name  \
# 0                       Pune to Goa
# 1                       Goa to Pune
# 2                     Mumbai to Goa
# 3                  Bangalore to Goa
# 4                  Goa to Bangalore
# 5                     Goa to Mumbai
# 6                 Pandharpur to Goa
# 7                 Goa to Pandharpur
# 8                    Solapur to Goa
# 9    Calangute (goa) to Goa Airport
# 10     Goa to Kolhapur(Maharashtra)
# 11                   Goa to Solapur
# 12                    Goa to Sangli
# 13   Goa Airport to Calangute (goa)
# 14         Goa to Sangola (Solapur)
# 15         Sangola (Solapur) to Goa
# 16  Mopa Airport to Calangute (goa)
# 17  Calangute (goa) to Mopa Airport
# 18              Goa to Mopa Airport
# 19                     Goa to Miraj
# 20            Panaji to Goa Airport
# 21              Mopa Airport to Goa
# 22                Shivamogga to Goa
# 23           Margao to Mopa Airport
# 24               Goa Airport to Goa
# 25                    Goa to Satara
# 26               Goa to Goa Airport
# 27            Goa Airport to Panaji
# 28                    Goa to Shirdi
# 29        Calangute (goa) to Panaji
# 30           Mopa Airport to Margao
# 31                Goa to Shivamogga
# 32           Calangute (goa) to Goa
# 33                  Belagavi to Goa
#
#                                            Route_link
# 0       https://www.redbus.in/bus-tickets/pune-to-goa
# 1       https://www.redbus.in/bus-tickets/goa-to-pune
# 2     https://www.redbus.in/bus-tickets/mumbai-to-goa
# 3   https://www.redbus.in/bus-tickets/bangalore-to...
# 4   https://www.redbus.in/bus-tickets/goa-to-banga...
# 5     https://www.redbus.in/bus-tickets/goa-to-mumbai
# 6   https://www.redbus.in/bus-tickets/pandharpur-t...
# 7   https://www.redbus.in/bus-tickets/goa-to-pandh...
# 8    https://www.redbus.in/bus-tickets/solapur-to-goa
# 9   https://www.redbus.in/bus-tickets/calangute-go...
# 10  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 11   https://www.redbus.in/bus-tickets/goa-to-solapur
# 12    https://www.redbus.in/bus-tickets/goa-to-sangli
# 13  https://www.redbus.in/bus-tickets/goa-airport-...
# 14   https://www.redbus.in/bus-tickets/goa-to-sangola
# 15   https://www.redbus.in/bus-tickets/sangola-to-goa
# 16  https://www.redbus.in/bus-tickets/mopa-airport...
# 17  https://www.redbus.in/bus-tickets/calangute-go...
# 18  https://www.redbus.in/bus-tickets/goa-to-mopa-...
# 19     https://www.redbus.in/bus-tickets/goa-to-miraj
# 20  https://www.redbus.in/bus-tickets/panaji-to-go...
# 21  https://www.redbus.in/bus-tickets/mopa-airport...
# 22   https://www.redbus.in/bus-tickets/shimoga-to-goa
# 23  https://www.redbus.in/bus-tickets/margoa-to-mo...
# 24  https://www.redbus.in/bus-tickets/goa-airport-...
# 25    https://www.redbus.in/bus-tickets/goa-to-satara
# 26  https://www.redbus.in/bus-tickets/goa-to-goa-a...
# 27  https://www.redbus.in/bus-tickets/goa-airport-...
# 28    https://www.redbus.in/bus-tickets/goa-to-shirdi
# 29  https://www.redbus.in/bus-tickets/calangute-go...
# 30  https://www.redbus.in/bus-tickets/mopa-airport...
# 31   https://www.redbus.in/bus-tickets/goa-to-shimoga
# 32  https://www.redbus.in/bus-tickets/calangute-go...
# 33  https://www.redbus.in/bus-tickets/belagavi-to-goa

# %%
    from selenium import webdriver
    from selenium.webdriver import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.common.exceptions import TimeoutException, NoSuchElementException
    import time
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    driver_G=webdriver.Chrome()
    Bus_names_G = []
    Bus_types_G = []
    Start_Time_G = []
    End_Time_G = []
    Ratings_G= []
    Total_Duration_G= []
    Prices_G =[]
    Seats_Available_G = []
    Route_names = []
    Route_links = []

    for i,r in GX.iterrows():
        link=r["Route_link"]
        routes=r["Route_name"]

        driver_G.get(link)
        time.sleep(2)

        elements=driver_G.find_elements(By.XPATH,f"//a[contains(@href, '{link}')]")
        for element in elements:
            element.click()
            time.sleep(2)

        time.sleep(2)
        scrolling=True
        while scrolling:
            old_page_source= driver_G.page_source

            ActionChains(driver_G).send_keys(Keys.PAGE_DOWN).perform()

            time.sleep(5)

            new_page_source= driver_G.page_source

            if new_page_source == old_page_source:
                scrolling = False


        bus_name = driver_G.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")
        bus_type = driver_G.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")
        start_time = driver_G.find_elements(By.XPATH,"//div[@class='dp-time f-19 d-color f-bold']")
        end_time = driver_G.find_elements(By.XPATH,"//div[@class='bp-time f-19 d-color disp-Inline']")
        total_duration = driver_G.find_elements(By.XPATH,"//div[@class='dur l-color lh-24']")
        try:
            rating = driver_G.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
        except:
            continue
        price = driver_G.find_elements(By.XPATH,'//div[@class="fare d-block"]')
        seats = driver_G.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")


        for bus in bus_name:
            Bus_names_G.append(bus.text)
            Route_links.append(link)
            Route_names.append(routes)
        for bus_type_elem in bus_type:
            Bus_types_G.append(bus_type_elem.text)
        for start_time_elem in start_time:
            Start_Time_G.append(start_time_elem.text)
        for end_time_elem in end_time:
            End_Time_G.append(end_time_elem.text)
        for total_duration_elem in total_duration:
            Total_Duration_G.append(total_duration_elem.text)
        for ratings in rating:
            Ratings_G.append(ratings.text)
        for price_elem in price:
            Prices_G.append(price_elem.text)
        for seats_elem in seats:
            Seats_Available_G.append(seats_elem.text)

 
    print("Successfully Completed")
# Out:
# Successfully Completed

# %%
    import pandas as pd
    data= {
        'Bus_name': Bus_names_G,
        'Bus_type': Bus_types_G,
        'Start_time': Start_Time_G,
        'End_time': End_Time_G,
        'Total_duration':Total_Duration_G,
        'Price': Prices_G,
        "Seats_Available":Seats_Available_G,
        "Ratings":Ratings_G,
        'Route_link': Route_links,
        'Route_name': Route_names
    }

    df_buses_6 = pd.DataFrame(data)
    path="df_buses_6.csv"
    df=df_buses_6.to_csv(path,index=False)

# %%
df_buses_6
# Out:
#                                               Bus_name  \
# 0    Kadamba Transport Corporation Limited (KTCL) -...
# 1                                    IntrCity SmartBus
# 2                            Dolphin Travel House (37)
# 3                                      AdGogte Shreyas
# 4                                       Ashray Travels
# ..                                                 ...
# 145  Kadamba Transport Corporation Limited (KTCL) -...
# 146  Kadamba Transport Corporation Limited (KTCL) -...
# 147  Kadamba Transport Corporation Limited (KTCL) -...
# 148                                   Sea Bird Tourist
# 149                      Yes Express Tours and Travels
#
#                                             Bus_type Start_time End_time  \
# 0                                  A/C Sleeper (2+1)      19:00    07:10
# 1              Bharat Benz A/C Seater /Sleeper (2+1)      19:30    08:05
# 2                      Bharat Benz A/C Sleeper (2+1)      18:30    06:00
# 3                                  A/C Sleeper (2+1)      19:45    10:00
# 4                      Bharat Benz A/C Sleeper (2+1)      18:05    09:00
# ..                                               ...        ...      ...
# 145                                 A/C Seater (2+1)      20:00    20:30
# 146                                 A/C Seater (2+3)      21:00    23:00
# 147                                 A/C Seater (2+3)      21:00    21:55
# 148                            NON A/C Sleeper (2+1)      17:30    02:30
# 149  Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)      23:00    15:30
#
#     Total_duration     Price     Seats_Available   Ratings  \
# 0          12h 10m   INR 900   2 Seats available  3.7\n338
# 1          12h 35m   INR 600  22 Seats available  4.4\n440
# 2          11h 30m   INR 910  12 Seats available  4.5\n228
# 3          14h 15m   INR 899   7 Seats available   4.0\n36
# 4          14h 55m   INR 900  12 Seats available  4.3\n655
# ..             ...       ...                 ...       ...
# 145        00h 30m   INR 150  15 Seats available       3.7
# 146        02h 00m   INR 400  47 Seats available       4.3
# 147        00h 55m   INR 200  47 Seats available       3.7
# 148        09h 00m   INR 700   8 Seats available   3.7\n13
# 149        16h 30m  INR 2490  29 Seats available       3.1
#
#                                             Route_link              Route_name
# 0        https://www.redbus.in/bus-tickets/pune-to-goa             Pune to Goa
# 1        https://www.redbus.in/bus-tickets/pune-to-goa             Pune to Goa
# 2        https://www.redbus.in/bus-tickets/pune-to-goa             Pune to Goa
# 3        https://www.redbus.in/bus-tickets/pune-to-goa             Pune to Goa
# 4        https://www.redbus.in/bus-tickets/pune-to-goa             Pune to Goa
# ..                                                 ...                     ...
# 145  https://www.redbus.in/bus-tickets/mopa-airport...  Mopa Airport to Margao
# 146  https://www.redbus.in/bus-tickets/mopa-airport...  Mopa Airport to Margao
# 147  https://www.redbus.in/bus-tickets/mopa-airport...  Mopa Airport to Margao
# 148   https://www.redbus.in/bus-tickets/goa-to-shimoga       Goa to Shivamogga
# 149  https://www.redbus.in/bus-tickets/belagavi-to-goa         Belagavi to Goa
#
# [150 rows x 10 columns]

# %%
                                                   #PUNJAB BUS DETAILS

import pandas as pd
PX=pd.read_csv("dfP.csv")
PX
# Out:
#                     Route_name  \
# 0             Delhi to Patiala
# 1             Patiala to Delhi
# 2            Delhi to Ludhiana
# 3            Ludhiana to Delhi
# 4           Jalandhar to Delhi
# 5           Delhi to Jalandhar
# 6     Delhi Airport to Patiala
# 7    Ludhiana to Delhi Airport
# 8    Delhi Airport to Ludhiana
# 9   Jalandhar to Delhi Airport
# 10   Phagwara to Delhi Airport
# 11           Delhi to Phagwara
# 12  Delhi Airport to Jalandhar
# 13           Phagwara to Delhi
# 14           Delhi to Amritsar
# 15           Amritsar to Delhi
# 16   Amritsar to Delhi Airport
# 17   Delhi Airport to Phagwara
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/delhi-to-pat...
# 1   https://www.redbus.in/bus-tickets/patiala-to-d...
# 2   https://www.redbus.in/bus-tickets/delhi-to-lud...
# 3   https://www.redbus.in/bus-tickets/ludhiana-to-...
# 4   https://www.redbus.in/bus-tickets/jalandhar-to...
# 5   https://www.redbus.in/bus-tickets/delhi-to-jal...
# 6   https://www.redbus.in/bus-tickets/delhi-airpor...
# 7   https://www.redbus.in/bus-tickets/ludhiana-to-...
# 8   https://www.redbus.in/bus-tickets/delhi-airpor...
# 9   https://www.redbus.in/bus-tickets/jalandhar-to...
# 10  https://www.redbus.in/bus-tickets/phagwara-to-...
# 11  https://www.redbus.in/bus-tickets/delhi-to-pha...
# 12  https://www.redbus.in/bus-tickets/delhi-airpor...
# 13  https://www.redbus.in/bus-tickets/phagwara-to-...
# 14  https://www.redbus.in/bus-tickets/delhi-to-amr...
# 15  https://www.redbus.in/bus-tickets/amritsar-to-...
# 16  https://www.redbus.in/bus-tickets/amritsar-to-...
# 17  https://www.redbus.in/bus-tickets/delhi-airpor...

# %%
    from selenium import webdriver
    from selenium.webdriver import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.common.exceptions import TimeoutException, NoSuchElementException
    import time
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    driver_P=webdriver.Chrome()
    Bus_names_P = []
    Bus_types_P = []
    Start_Time_P = []
    End_Time_P = []
    Ratings_P= []
    Total_Duration_P= []
    Prices_P =[]
    Seats_Available_P = []
    Route_names = []
    Route_links = []

    for i,r in PX.iterrows():
        link=r["Route_link"]
        routes=r["Route_name"]

        driver_P.get(link)
        time.sleep(2)

        elements=driver_P.find_elements(By.XPATH,f"//a[contains(@href, '{link}')]")
        for element in elements:
            element.click()
            time.sleep(2)
        
        try:
            clicks = driver_P.find_element(By.XPATH,"//div[@class='button']")
            clicks.click()
        except:
            continue
        time.sleep(2)

        scrolling=True
        while scrolling:
            old_page_source= driver_P.page_source

            ActionChains(driver_P).send_keys(Keys.PAGE_DOWN).perform()

            time.sleep(5)

            new_page_source= driver_P.page_source

            if new_page_source == old_page_source:
                scrolling = False


        bus_name = driver_P.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")
        bus_type = driver_P.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")
        start_time = driver_P.find_elements(By.XPATH,"//div[@class='dp-time f-19 d-color f-bold']")
        end_time = driver_P.find_elements(By.XPATH,"//div[@class='bp-time f-19 d-color disp-Inline']")
        total_duration = driver_P.find_elements(By.XPATH,"//div[@class='dur l-color lh-24']")
        try:
            rating = driver_P.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
        except:
            continue
        price = driver_P.find_elements(By.XPATH,'//div[@class="fare d-block"]')
        seats = driver_P.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")


        for bus in bus_name:
            Bus_names_P.append(bus.text)
            Route_links.append(link)
            Route_names.append(routes)
        for bus_type_elem in bus_type:
            Bus_types_P.append(bus_type_elem.text)
        for start_time_elem in start_time:
            Start_Time_P.append(start_time_elem.text)
        for end_time_elem in end_time:
            End_Time_P.append(end_time_elem.text)
        for total_duration_elem in total_duration:
            Total_Duration_P.append(total_duration_elem.text)
        for ratings in rating:
            Ratings_P.append(ratings.text)
        for price_elem in price:
            Prices_P.append(price_elem.text)
        for seats_elem in seats:
            Seats_Available_P.append(seats_elem.text)

 
    print("Successfully Completed")
# Out:
# Successfully Completed

# %%
    import pandas as pd
    data= {
        'Bus_name': Bus_names_P,
        'Bus_type': Bus_types_P,
        'Start_time': Start_Time_P,
        'End_time': End_Time_P,
        'Total_duration':Total_Duration_P,
        'Price': Prices_P,
        "Seats_Available":Seats_Available_P,
        "Ratings":Ratings_P,
        'Route_link': Route_links,
        'Route_name': Route_names
    }

    df_buses_7 = pd.DataFrame(data)
    path="df_buses_7.csv"
    df=df_buses_7.to_csv(path,index=False)

# %%
df_buses_7
# Out:
#                               Bus_name                               Bus_type  \
# 0                       RSRTC - 156675              Express Non AC Seater 2+3
# 1                             Yolo Bus          Bharat Benz A/C Sleeper (2+1)
# 2                       Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)
# 3    AdGolden Temple Volvo Bus Service             A/C Seater / Sleeper (2+2)
# 4                       Laxmi holidays                   VE A/C Sleeper (2+1)
# ..                                 ...                                    ...
# 123                     Laxmi holidays          Bharat Benz A/C Sleeper (2+1)
# 124                       Zingbus Plus  Bharat Benz A/C Seater /Sleeper (2+1)
# 125                  IntrCity SmartBus             A/C Seater / Sleeper (2+1)
# 126                       Zingbus Plus          Scania A/C Semi Sleeper (2+2)
# 127                  IntrCity SmartBus             A/C Seater / Sleeper (2+1)
#
#     Start_time End_time Total_duration    Price     Seats_Available   Ratings  \
# 0        22:30    05:15        06h 45m  INR 436  36 Seats available    2.2\n6
# 1        23:05    04:44        05h 39m  INR 600  19 Seats available  4.6\n377
# 2        22:20    05:00        06h 40m  INR 484  26 Seats available  4.6\n329
# 3        23:40    05:00        05h 20m      561  45 Seats available   3.2\n48
# 4        23:00    06:00        07h 00m      599  32 Seats available  4.4\n344
# ..         ...      ...            ...      ...                 ...       ...
# 123      23:35    07:00        07h 25m      599  16 Seats available   4.6\n40
# 124      22:45    06:40        07h 55m      510  25 Seats available   4.7\n15
# 125      22:00    04:35        06h 35m  INR 659  13 Seats available   4.7\n26
# 126      23:15    07:25        08h 10m      424  30 Seats available   4.5\n45
# 127      21:25    04:30        07h 05m  INR 559  19 Seats available   3.8\n39
#
#                                             Route_link         Route_name
# 0    https://www.redbus.in/bus-tickets/delhi-to-lud...  Delhi to Ludhiana
# 1    https://www.redbus.in/bus-tickets/delhi-to-lud...  Delhi to Ludhiana
# 2    https://www.redbus.in/bus-tickets/delhi-to-lud...  Delhi to Ludhiana
# 3    https://www.redbus.in/bus-tickets/delhi-to-lud...  Delhi to Ludhiana
# 4    https://www.redbus.in/bus-tickets/delhi-to-lud...  Delhi to Ludhiana
# ..                                                 ...                ...
# 123  https://www.redbus.in/bus-tickets/phagwara-to-...  Phagwara to Delhi
# 124  https://www.redbus.in/bus-tickets/phagwara-to-...  Phagwara to Delhi
# 125  https://www.redbus.in/bus-tickets/phagwara-to-...  Phagwara to Delhi
# 126  https://www.redbus.in/bus-tickets/phagwara-to-...  Phagwara to Delhi
# 127  https://www.redbus.in/bus-tickets/phagwara-to-...  Phagwara to Delhi
#
# [128 rows x 10 columns]

# %%
                              #UTTAR PRADESH BUS DETAILS

import pandas as pd
UPX=pd.read_csv("dfUP.csv")
UPX
# Out:
#                                            Route_name  \
# 0                                   Delhi to Bareilly
# 1                                   Bareilly to Delhi
# 2                    Aligarh (uttar pradesh) to Delhi
# 3                    Delhi to Aligarh (uttar pradesh)
# 4                                Lucknow to Allahabad
# 5                                    Lucknow to Delhi
# 6                Delhi to Farrukhabad (Uttar Pradesh)
# 7                Farrukhabad (Uttar Pradesh) to Delhi
# 8                                     Badaun to Delhi
# 9                                Allahabad to Lucknow
# 10                                    Lucknow to Agra
# 11                   Sitapur (Uttar Pradesh) to Delhi
# 12                                    Delhi to Badaun
# 13                   Delhi to Sitapur (Uttar Pradesh)
# 14                                      Agra to Delhi
# 15                                 Delhi to Moradabad
# 16                                   Delhi to Lucknow
# 17                                    Agra to Lucknow
# 18                                Lucknow to Varanasi
# 19                                   Agra to Bareilly
# 20                                Lucknow to Bareilly
# 21                                   Bareilly to Agra
# 22                                      Delhi to Agra
# 23                                Varanasi to Lucknow
# 24                                 Moradabad to Delhi
# 25                   Kanpur (Uttar Pradesh) to Jhansi
# 26              Delhi to Shahjahanpur (Uttar Pradesh)
# 27              Shahjahanpur (Uttar Pradesh) to Delhi
# 28               Gorakhpur (uttar pradesh) to Lucknow
# 29                 Kanpur (Uttar Pradesh) to Bareilly
# 30                 Lucknow to Aligarh (uttar pradesh)
# 31                  Lucknow to Kanpur (Uttar Pradesh)
# 32                                  Delhi to Pilibhit
# 33                                  Lucknow to Ballia
# 34                      Delhi to Etah (Uttar Pradesh)
# 35               Lucknow to Gorakhpur (uttar pradesh)
# 36                 Aligarh (uttar pradesh) to Lucknow
# 37                    Aligarh (uttar pradesh) to Agra
# 38                               Bareilly to Dehradun
# 39                                  Pilibhit to Delhi
# 40                                Bareilly to Lucknow
# 41                                  Delhi to Dehradun
# 42                              Varanasi to Allahabad
# 43                                 Lucknow to Mathura
# 44                   Jhansi to Kanpur (Uttar Pradesh)
# 45                               Dehradun to Bareilly
# 46                  Kanpur (Uttar Pradesh) to Lucknow
# 47  Aligarh (uttar pradesh) to Greater noida (utta...
# 48                      Etah (Uttar Pradesh) to Delhi
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/delhi-to-bar...
# 1   https://www.redbus.in/bus-tickets/bareilly-to-...
# 2   https://www.redbus.in/bus-tickets/aligarh-utta...
# 3   https://www.redbus.in/bus-tickets/delhi-to-ali...
# 4   https://www.redbus.in/bus-tickets/lucknow-to-a...
# 5   https://www.redbus.in/bus-tickets/lucknow-to-d...
# 6   https://www.redbus.in/bus-tickets/delhi-to-far...
# 7   https://www.redbus.in/bus-tickets/farrukhabad-...
# 8   https://www.redbus.in/bus-tickets/badaun-to-delhi
# 9   https://www.redbus.in/bus-tickets/allahabad-to...
# 10  https://www.redbus.in/bus-tickets/lucknow-to-agra
# 11  https://www.redbus.in/bus-tickets/sitapur-to-d...
# 12  https://www.redbus.in/bus-tickets/delhi-to-badaun
# 13  https://www.redbus.in/bus-tickets/delhi-to-sit...
# 14    https://www.redbus.in/bus-tickets/agra-to-delhi
# 15  https://www.redbus.in/bus-tickets/delhi-to-mor...
# 16  https://www.redbus.in/bus-tickets/delhi-to-luc...
# 17  https://www.redbus.in/bus-tickets/agra-to-lucknow
# 18  https://www.redbus.in/bus-tickets/lucknow-to-v...
# 19  https://www.redbus.in/bus-tickets/agra-to-bare...
# 20  https://www.redbus.in/bus-tickets/lucknow-to-b...
# 21  https://www.redbus.in/bus-tickets/bareilly-to-...
# 22    https://www.redbus.in/bus-tickets/delhi-to-agra
# 23  https://www.redbus.in/bus-tickets/varanasi-to-...
# 24  https://www.redbus.in/bus-tickets/moradabad-to...
# 25  https://www.redbus.in/bus-tickets/kanpur-to-jh...
# 26  https://www.redbus.in/bus-tickets/delhi-to-sha...
# 27  https://www.redbus.in/bus-tickets/shahjahanpur...
# 28  https://www.redbus.in/bus-tickets/gorakhpur-to...
# 29  https://www.redbus.in/bus-tickets/kanpur-to-ba...
# 30  https://www.redbus.in/bus-tickets/lucknow-to-a...
# 31  https://www.redbus.in/bus-tickets/lucknow-to-k...
# 32  https://www.redbus.in/bus-tickets/delhi-to-pil...
# 33  https://www.redbus.in/bus-tickets/lucknow-to-b...
# 34  https://www.redbus.in/bus-tickets/delhi-to-eta...
# 35  https://www.redbus.in/bus-tickets/lucknow-to-g...
# 36  https://www.redbus.in/bus-tickets/aligarh-to-l...
# 37  https://www.redbus.in/bus-tickets/aligarh-to-agra
# 38  https://www.redbus.in/bus-tickets/bareilly-to-...
# 39  https://www.redbus.in/bus-tickets/pilibhit-to-...
# 40  https://www.redbus.in/bus-tickets/bareilly-to-...
# 41  https://www.redbus.in/bus-tickets/delhi-to-deh...
# 42  https://www.redbus.in/bus-tickets/varanasi-to-...
# 43  https://www.redbus.in/bus-tickets/lucknow-to-m...
# 44  https://www.redbus.in/bus-tickets/jhansi-to-ka...
# 45  https://www.redbus.in/bus-tickets/dehradun-to-...
# 46  https://www.redbus.in/bus-tickets/kanpur-to-lu...
# 47  https://www.redbus.in/bus-tickets/aligarh-to-g...
# 48  https://www.redbus.in/bus-tickets/etah-up-to-d...

# %%
    from selenium import webdriver
    from selenium.webdriver import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.common.exceptions import TimeoutException, NoSuchElementException
    import time
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    driver_UP=webdriver.Chrome()
    Bus_names_UP = []
    Bus_types_UP = []
    Start_Time_UP = []
    End_Time_UP = []
    Ratings_UP= []
    Total_Duration_UP= []
    Prices_UP =[]
    Seats_Available_UP = []
    Route_names = []
    Route_links = []

    for i,r in UPX.iterrows():
        link=r["Route_link"]
        routes=r["Route_name"]

        driver_UP.get(link)
        time.sleep(2)

        elements=driver_UP.find_elements(By.XPATH,f"//a[contains(@href, '{link}')]")
        for element in elements:
            element.click()
            time.sleep(2)

        try:
            clicks = driver_UP.find_element(By.XPATH,"//div[@class='button']")
            clicks.click()
        except:
            continue
        time.sleep(2)

        scrolling=True
        while scrolling:
            old_page_source= driver_UP.page_source

            ActionChains(driver_UP).send_keys(Keys.PAGE_DOWN).perform()

            time.sleep(5)

            new_page_source= driver_UP.page_source

            if new_page_source == old_page_source:
                scrolling = False


        bus_name = driver_UP.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")
        bus_type = driver_UP.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")
        start_time = driver_UP.find_elements(By.XPATH,"//div[@class='dp-time f-19 d-color f-bold']")
        end_time = driver_UP.find_elements(By.XPATH,"//div[@class='bp-time f-19 d-color disp-Inline']")
        total_duration = driver_UP.find_elements(By.XPATH,"//div[@class='dur l-color lh-24']")
        try:
            rating = driver_UP.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
        except:
            continue
        price = driver_UP.find_elements(By.XPATH,'//div[@class="fare d-block"]')
        seats = driver_UP.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")


        for bus in bus_name:
            Bus_names_UP.append(bus.text)
            Route_links.append(link)
            Route_names.append(routes)
        for bus_type_elem in bus_type:
            Bus_types_UP.append(bus_type_elem.text)
        for start_time_elem in start_time:
            Start_Time_UP.append(start_time_elem.text)
        for end_time_elem in end_time:
            End_Time_UP.append(end_time_elem.text)
        for total_duration_elem in total_duration:
            Total_Duration_UP.append(total_duration_elem.text)
        for ratings in rating:
            Ratings_UP.append(ratings.text)
        for price_elem in price:
            Prices_UP.append(price_elem.text)
        for seats_elem in seats:
            Seats_Available_UP.append(seats_elem.text)

 
    print("Successfully Completed")
# Out:
# Successfully Completed

# %%
    import pandas as pd
    data= {
        'Bus_name': Bus_names_UP,
        'Bus_type': Bus_types_UP,
        'Start_time': Start_Time_UP,
        'End_time': End_Time_UP,
        'Total_duration':Total_Duration_UP,
        'Price': Prices_UP,
        "Seats_Available":Seats_Available_UP,
        "Ratings":Ratings_UP,
        'Route_link': Route_links,
        'Route_name': Route_names
    }

    df_buses_8 = pd.DataFrame(data)
    path="df_buses_8.csv"
    df=df_buses_8.to_csv(path,index=False)

# %%
df_buses_8
# Out:
#                     Bus_name                               Bus_type  \
# 0           UPSRTC - HDD0105             Rajdhani Non AC Seater 2+3
# 1           UPSRTC - LKM0400                 Shatabdi AC Seater 2+2
# 2           UPSRTC - AWD0240                  Janrath AC Seater 2+3
# 3           UPSRTC - HDD0147             Ordinary Non AC Seater 2+3
# 4           UPSRTC - BRT0063             Ordinary Non AC Seater 2+3
# ..                       ...                                    ...
# 283  Anshi Raj Shree Travels  Bharat Benz A/C Seater /Sleeper (2+1)
# 284         Shatabdi Travels          Bharat Benz A/C Sleeper (2+1)
# 285            Kamla Travels                      A/C Sleeper (2+1)
# 286   Vijay Tour and Travels  Bharat Benz A/C Seater /Sleeper (2+1)
# 287            Kamla Travels         Non A/C Seater / Sleeper (2+1)
#
#     Start_time End_time Total_duration    Price     Seats_Available  Ratings  \
# 0        20:00    01:41        05h 41m  INR 450  51 Seats available      3.3
# 1        20:02    01:30        05h 28m  INR 604  37 Seats available      3.3
# 2        20:02    02:15        06h 13m  INR 520  48 Seats available   3.3\n2
# 3        20:03    02:01        05h 58m  INR 444  52 Seats available      3.3
# 4        20:30    03:40        07h 10m  INR 448  52 Seats available      3.3
# ..         ...      ...            ...      ...                 ...      ...
# 283      23:30    03:15        03h 45m  INR 999   8 Seats available   3.5\n5
# 284      23:45    04:45        05h 00m  INR 749    1 Seat available  3.8\n41
# 285      23:55    05:00        05h 05m  INR 899   2 Seats available   5.0\n1
# 286      21:30    02:30        05h 00m  INR 599  18 Seats available  2.4\n11
# 287      23:55    05:00        05h 05m  INR 900    1 Seat available   1.0\n5
#
#                                             Route_link  \
# 0    https://www.redbus.in/bus-tickets/delhi-to-bar...
# 1    https://www.redbus.in/bus-tickets/delhi-to-bar...
# 2    https://www.redbus.in/bus-tickets/delhi-to-bar...
# 3    https://www.redbus.in/bus-tickets/delhi-to-bar...
# 4    https://www.redbus.in/bus-tickets/delhi-to-bar...
# ..                                                 ...
# 283  https://www.redbus.in/bus-tickets/jhansi-to-ka...
# 284  https://www.redbus.in/bus-tickets/jhansi-to-ka...
# 285  https://www.redbus.in/bus-tickets/jhansi-to-ka...
# 286  https://www.redbus.in/bus-tickets/jhansi-to-ka...
# 287  https://www.redbus.in/bus-tickets/jhansi-to-ka...
#
#                            Route_name
# 0                   Delhi to Bareilly
# 1                   Delhi to Bareilly
# 2                   Delhi to Bareilly
# 3                   Delhi to Bareilly
# 4                   Delhi to Bareilly
# ..                                ...
# 283  Jhansi to Kanpur (Uttar Pradesh)
# 284  Jhansi to Kanpur (Uttar Pradesh)
# 285  Jhansi to Kanpur (Uttar Pradesh)
# 286  Jhansi to Kanpur (Uttar Pradesh)
# 287  Jhansi to Kanpur (Uttar Pradesh)
#
# [288 rows x 10 columns]

# %%
                                #ASSAM BUS DETAILS                  

import pandas as pd
ASX=pd.read_csv("dfAS.csv")
ASX
# Out:
#                              Route_name  \
# 0                    Tezpur to Guwahati
# 1                    Guwahati to Tezpur
# 2            Guwahati to Nagaon (Assam)
# 3            Nagaon (Assam) to Guwahati
# 4                  Goalpara to Guwahati
# 5             Jorhat to North Lakhimpur
# 6                    Dhubri to Guwahati
# 7                   Jorhat to Dibrugarh
# 8             North Lakhimpur to Jorhat
# 9           North Lakhimpur to Sibsagar
# 10                   Guwahati to Dhubri
# 11               Dhekiajuli to Guwahati
# 12          Sibsagar to North Lakhimpur
# 13                  Dibrugarh to Jorhat
# 14                    Jorhat to Dhemaji
# 15                   Jorhat to Tinsukia
# 16                  Tezpur to Dibrugarh
# 17                    Dhemaji to Jorhat
# 18            North Lakhimpur to Tezpur
# 19        Guwahati to Biswanath Charali
# 20         North Lakhimpur to Dibrugarh
# 21                   Tinsukia to Jorhat
# 22            Tezpur to North Lakhimpur
# 23             North Lakhimpur to Moran
# 24                   Guwahati to Gohpur
# 25                 Guwahati to Kaliabor
# 26  Guwahati to Tumuki (Tezpur Medical)
# 27                  Dibrugarh to Tezpur
# 28        Biswanath Charali to Guwahati
# 29         Dibrugarh to North Lakhimpur
# 30             Moran to North Lakhimpur
# 31  Tumuki (Tezpur Medical) to Guwahati
# 32       Biswanath Charali to Dibrugarh
# 33                   Gohpur to Guwahati
# 34                  Sibsagar to Dhemaji
# 35          North Lakhimpur to Guwahati
# 36                  Haflong to Guwahati
# 37                      Tezpur to Moran
# 38                      Moran to Tezpur
# 39                Bokakhat to Dibrugarh
# 40    North Lakhimpur to Nagaon (Assam)
# 41                Bihpuria to Dibrugarh
# 42            Haflong to Nagaon (Assam)
# 43                 Guwahati to Golaghat
# 44                   Jorhat to Gogamukh
# 45       Dibrugarh to Biswanath Charali
# 46          Golaghat to North Lakhimpur
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/tezpur-to-gu...
# 1   https://www.redbus.in/bus-tickets/guwahati-to-...
# 2   https://www.redbus.in/bus-tickets/guwahati-to-...
# 3   https://www.redbus.in/bus-tickets/nagaon-to-gu...
# 4   https://www.redbus.in/bus-tickets/goalpara-to-...
# 5   https://www.redbus.in/bus-tickets/jorhat-to-no...
# 6   https://www.redbus.in/bus-tickets/dhubri-to-gu...
# 7   https://www.redbus.in/bus-tickets/jorhat-to-di...
# 8   https://www.redbus.in/bus-tickets/north-lakhim...
# 9   https://www.redbus.in/bus-tickets/north-lakhim...
# 10  https://www.redbus.in/bus-tickets/guwahati-to-...
# 11  https://www.redbus.in/bus-tickets/dhekiajuli-t...
# 12  https://www.redbus.in/bus-tickets/sibsagar-to-...
# 13  https://www.redbus.in/bus-tickets/dibrugarh-to...
# 14  https://www.redbus.in/bus-tickets/jorhat-to-dh...
# 15  https://www.redbus.in/bus-tickets/jorhat-to-ti...
# 16  https://www.redbus.in/bus-tickets/tezpur-to-di...
# 17  https://www.redbus.in/bus-tickets/dhemaji-to-j...
# 18  https://www.redbus.in/bus-tickets/north-lakhim...
# 19  https://www.redbus.in/bus-tickets/guwahati-to-...
# 20  https://www.redbus.in/bus-tickets/north-lakhim...
# 21  https://www.redbus.in/bus-tickets/tinsukia-to-...
# 22  https://www.redbus.in/bus-tickets/tezpur-to-no...
# 23  https://www.redbus.in/bus-tickets/north-lakhim...
# 24  https://www.redbus.in/bus-tickets/guwahati-to-...
# 25  https://www.redbus.in/bus-tickets/guwahati-to-...
# 26  https://www.redbus.in/bus-tickets/guwahati-to-...
# 27  https://www.redbus.in/bus-tickets/dibrugarh-to...
# 28  https://www.redbus.in/bus-tickets/biswanath-ch...
# 29  https://www.redbus.in/bus-tickets/dibrugarh-to...
# 30  https://www.redbus.in/bus-tickets/moran-to-nor...
# 31  https://www.redbus.in/bus-tickets/tumuki-tezpu...
# 32  https://www.redbus.in/bus-tickets/biswanath-ch...
# 33  https://www.redbus.in/bus-tickets/gohpur-to-gu...
# 34  https://www.redbus.in/bus-tickets/sibsagar-to-...
# 35  https://www.redbus.in/bus-tickets/north-lakhim...
# 36  https://www.redbus.in/bus-tickets/haflong-to-g...
# 37  https://www.redbus.in/bus-tickets/tezpur-to-moran
# 38  https://www.redbus.in/bus-tickets/moran-to-tezpur
# 39  https://www.redbus.in/bus-tickets/bokakhat-to-...
# 40  https://www.redbus.in/bus-tickets/north-lakhim...
# 41  https://www.redbus.in/bus-tickets/bihpuria-to-...
# 42  https://www.redbus.in/bus-tickets/haflong-to-n...
# 43  https://www.redbus.in/bus-tickets/guwahati-to-...
# 44  https://www.redbus.in/bus-tickets/jorhat-to-go...
# 45  https://www.redbus.in/bus-tickets/dibrugarh-to...
# 46  https://www.redbus.in/bus-tickets/golaghat-to-...

# %%
    from selenium import webdriver
    from selenium.webdriver import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.common.exceptions import TimeoutException, NoSuchElementException
    import time
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    driver_AS=webdriver.Chrome()
    Bus_names_AS = []
    Bus_types_AS = []
    Start_Time_AS = []
    End_Time_AS = []
    Ratings_AS= []
    Total_Duration_AS= []
    Prices_AS =[]
    Seats_Available_AS = []
    Route_names = []
    Route_links = []

    for i,r in ASX.iterrows():
        link=r["Route_link"]
        routes=r["Route_name"]

        driver_AS.get(link)
        time.sleep(2)

        elements=driver_AS.find_elements(By.XPATH,f"//a[contains(@href, '{link}')]")
        for element in elements:
            element.click()
            time.sleep(2)

        try:
            clicks = driver_AS.find_element(By.XPATH,"//div[@class='button']")
            clicks.click()
        except:
            continue
        time.sleep(2)

        scrolling=True
        while scrolling:
            old_page_source= driver_AS.page_source

            ActionChains(driver_AS).send_keys(Keys.PAGE_DOWN).perform()

            time.sleep(5)

            new_page_source= driver_AS.page_source

            if new_page_source == old_page_source:
                scrolling = False


        bus_name = driver_AS.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")
        bus_type = driver_AS.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")
        start_time = driver_AS.find_elements(By.XPATH,"//div[@class='dp-time f-19 d-color f-bold']")
        end_time = driver_AS.find_elements(By.XPATH,"//div[@class='bp-time f-19 d-color disp-Inline']")
        total_duration = driver_AS.find_elements(By.XPATH,"//div[@class='dur l-color lh-24']")
        try:
            rating = driver_AS.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
        except:
            continue
        price = driver_AS.find_elements(By.XPATH,'//div[@class="fare d-block"]')
        seats = driver_AS.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")


        for bus in bus_name:
            Bus_names_AS.append(bus.text)
            Route_links.append(link)
            Route_names.append(routes)
        for bus_type_elem in bus_type:
            Bus_types_AS.append(bus_type_elem.text)
        for start_time_elem in start_time:
            Start_Time_AS.append(start_time_elem.text)
        for end_time_elem in end_time:
            End_Time_AS.append(end_time_elem.text)
        for total_duration_elem in total_duration:
            Total_Duration_AS.append(total_duration_elem.text)
        for ratings in rating:
            Ratings_AS.append(ratings.text)
        for price_elem in price:
            Prices_AS.append(price_elem.text)
        for seats_elem in seats:
            Seats_Available_AS.append(seats_elem.text)

 
    print("Successfully Completed")
# Out:
# Successfully Completed

# %%
    import pandas as pd
    data= {
        'Bus_name': Bus_names_AS,
        'Bus_type': Bus_types_AS,
        'Start_time': Start_Time_AS,
        'End_time': End_Time_AS,
        'Total_duration':Total_Duration_AS,
        'Price': Prices_AS,
        "Seats_Available":Seats_Available_AS,
        "Ratings":Ratings_AS,
        'Route_link': Route_links,
        'Route_name': Route_names
    }

    df_buses_9 = pd.DataFrame(data)
    path="df_buses_9.csv"
    df=df_buses_9.to_csv(path,index=False)

# %%
df_buses_9
# Out:
#                                               Bus_name  \
# 0    Assam State Transport Corporation (ASTC) - 135927
# 1    Assam State Transport Corporation (ASTC) - 156885
# 2    Assam State Transport Corporation (ASTC) - 153223
# 3    Assam State Transport Corporation (ASTC) - 170878
# 4    Assam State Transport Corporation (ASTC) - 157959
# ..                                                 ...
# 149                                      Yatra Travels
# 150                                       Deep Travels
# 151                                    Drishti Travels
# 152                                    Drishti Travels
# 153                        PARIJAT TRAVELS(UNDER ASTC)
#
#                          Bus_type Start_time End_time Total_duration    Price  \
# 0             Volvo AC Seater 2+2      07:10    11:40        04h 30m  INR 298
# 1    Bharat Benz A/C Seater (2+2)      07:35    12:00        04h 25m  INR 298
# 2    Bharat Benz A/C Seater (2+2)      09:15    13:30        04h 15m  INR 298
# 3    Bharat Benz A/C Seater (2+2)      10:35    15:15        04h 40m  INR 298
# 4    Bharat Benz A/C Seater (2+2)      14:00    18:30        04h 30m  INR 298
# ..                            ...        ...      ...            ...      ...
# 149  NON AC Seater/ Sleeper (2+1)      22:30    06:15        07h 45m      450
# 150   NON AC Seater / Sleeper 2+1      22:20    05:00        06h 40m  INR 499
# 151          NON A/C Seater (2+1)      21:00    05:00        08h 00m      432
# 152          NON A/C Seater (2+1)      21:00    05:30        08h 30m      432
# 153          NON A/C Seater (2+1)      23:11    06:30        07h 19m      375
#
#         Seats_Available   Ratings  \
# 0    15 Seats available  4.3\n331
# 1    28 Seats available   4.6\n19
# 2    26 Seats available  4.1\n102
# 3    19 Seats available   4.6\n83
# 4    28 Seats available  4.3\n214
# ..                  ...       ...
# 149  28 Seats available   4.5\n26
# 150  28 Seats available   4.1\n28
# 151  23 Seats available   3.6\n19
# 152  20 Seats available   3.1\n22
# 153  21 Seats available   3.6\n25
#
#                                             Route_link          Route_name
# 0    https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 1    https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 2    https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 3    https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 4    https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# ..                                                 ...                 ...
# 149  https://www.redbus.in/bus-tickets/gohpur-to-gu...  Gohpur to Guwahati
# 150  https://www.redbus.in/bus-tickets/gohpur-to-gu...  Gohpur to Guwahati
# 151  https://www.redbus.in/bus-tickets/gohpur-to-gu...  Gohpur to Guwahati
# 152  https://www.redbus.in/bus-tickets/gohpur-to-gu...  Gohpur to Guwahati
# 153  https://www.redbus.in/bus-tickets/gohpur-to-gu...  Gohpur to Guwahati
#
# [154 rows x 10 columns]

# %%
                             #HARYANA BUS DETAILS

import pandas as pd
HX=pd.read_csv("dfH.csv")
HX
# Out:
#                                       Route_name  \
# 0                                Delhi to Shimla
# 1      Chandigarh to Hamirpur (Himachal Pradesh)
# 2      Hamirpur (Himachal Pradesh) to Chandigarh
# 3                                Shimla to Delhi
# 4                            Delhi to Chandigarh
# 5           Hamirpur (Himachal Pradesh) to Delhi
# 6        Chamba (Himachal Pradesh) to Chandigarh
# 7           Delhi to Hamirpur (Himachal Pradesh)
# 8   Chandigarh to Dharamshala (Himachal Pradesh)
# 9             Delhi to Chamba (Himachal Pradesh)
# 10            Chamba (Himachal Pradesh) to Delhi
# 11                          Kangra to Chandigarh
# 12                          Shimla to Chandigarh
# 13             Delhi to Baddi (Himachal Pradesh)
# 14                                Delhi to Solan
# 15                             Delhi to Nalagarh
# 16  Dharamshala (Himachal Pradesh) to Chandigarh
# 17                        Palampur to Chandigarh
# 18                            Ghumarwin to Delhi
# 19                          Chandigarh to Kangra
# 20             Baddi (Himachal Pradesh) to Delhi
# 21                          Manali to Chandigarh
# 22                                Solan to Delhi
# 23                          Chandigarh to Manali
# 24                            Delhi to Sarkaghat
# 25                       Ghumarwin to Chandigarh
# 26                           Chandigarh to Kullu
# 27          Delhi to Bilaspur (Himachal Pradesh)
# 28                            Delhi to Ghumarwin
# 29           Chamba (Himachal Pradesh) to Shimla
# 30                             Delhi to Palampur
# 31  Chandigarh to Reckong Peo (Himachal Pradesh)
# 32          Bilaspur (Himachal Pradesh) to Delhi
# 33                            Sarkaghat to Delhi
# 34                               Manali to Delhi
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/delhi-to-shimla
# 1   https://www.redbus.in/bus-tickets/chandigarh-t...
# 2   https://www.redbus.in/bus-tickets/hamirpur-him...
# 3   https://www.redbus.in/bus-tickets/shimla-to-delhi
# 4   https://www.redbus.in/bus-tickets/delhi-to-cha...
# 5   https://www.redbus.in/bus-tickets/hamirpur-him...
# 6   https://www.redbus.in/bus-tickets/chamba-himac...
# 7   https://www.redbus.in/bus-tickets/delhi-to-ham...
# 8   https://www.redbus.in/bus-tickets/chandigarh-t...
# 9   https://www.redbus.in/bus-tickets/delhi-to-cha...
# 10  https://www.redbus.in/bus-tickets/chamba-himac...
# 11  https://www.redbus.in/bus-tickets/kangra-to-ch...
# 12  https://www.redbus.in/bus-tickets/shimla-to-ch...
# 13  https://www.redbus.in/bus-tickets/delhi-to-bad...
# 14   https://www.redbus.in/bus-tickets/delhi-to-solan
# 15  https://www.redbus.in/bus-tickets/delhi-to-nal...
# 16  https://www.redbus.in/bus-tickets/dharamshala-...
# 17  https://www.redbus.in/bus-tickets/palampur-to-...
# 18  https://www.redbus.in/bus-tickets/ghumarwin-to...
# 19  https://www.redbus.in/bus-tickets/chandigarh-t...
# 20  https://www.redbus.in/bus-tickets/baddi-himach...
# 21  https://www.redbus.in/bus-tickets/manali-to-ch...
# 22   https://www.redbus.in/bus-tickets/solan-to-delhi
# 23  https://www.redbus.in/bus-tickets/chandigarh-t...
# 24  https://www.redbus.in/bus-tickets/delhi-to-sar...
# 25  https://www.redbus.in/bus-tickets/ghumarwin-to...
# 26  https://www.redbus.in/bus-tickets/chandigarh-t...
# 27  https://www.redbus.in/bus-tickets/delhi-to-bil...
# 28  https://www.redbus.in/bus-tickets/delhi-to-ghu...
# 29  https://www.redbus.in/bus-tickets/chamba-himac...
# 30  https://www.redbus.in/bus-tickets/delhi-to-pal...
# 31  https://www.redbus.in/bus-tickets/chandigarh-t...
# 32  https://www.redbus.in/bus-tickets/bilaspur-him...
# 33  https://www.redbus.in/bus-tickets/sarkaghat-to...
# 34  https://www.redbus.in/bus-tickets/manali-to-delhi

# %%
    from selenium import webdriver
    from selenium.webdriver import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.common.exceptions import TimeoutException, NoSuchElementException
    import time
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    driver_H=webdriver.Chrome()
    Bus_names_H = []
    Bus_types_H = []
    Start_Time_H = []
    End_Time_H = []
    Ratings_H= []
    Total_Duration_H= []
    Prices_H =[]
    Seats_Available_H = []
    Route_names = []
    Route_links = []

    for i,r in HX.iterrows():
        link=r["Route_link"]
        routes=r["Route_name"]

        driver_H.get(link)
        time.sleep(2)

        elements=driver_H.find_elements(By.XPATH,f"//a[contains(@href, '{link}')]")
        for element in elements:
            element.click()
            time.sleep(2)

        try:
            clicks = driver_H.find_element(By.XPATH,"//div[@class='button']")
            clicks.click()
        except:
            continue
        time.sleep(2)

        scrolling=True
        while scrolling:
            old_page_source= driver_H.page_source

            ActionChains(driver_H).send_keys(Keys.PAGE_DOWN).perform()

            time.sleep(5)

            new_page_source= driver_H.page_source

            if new_page_source == old_page_source:
                scrolling = False


        bus_name = driver_H.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")
        bus_type = driver_H.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")
        start_time = driver_H.find_elements(By.XPATH,"//div[@class='dp-time f-19 d-color f-bold']")
        end_time = driver_H.find_elements(By.XPATH,"//div[@class='bp-time f-19 d-color disp-Inline']")
        total_duration = driver_H.find_elements(By.XPATH,"//div[@class='dur l-color lh-24']")
        try:
            rating = driver_H.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
        except:
            continue
        price = driver_H.find_elements(By.XPATH,'//div[@class="fare d-block"]')
        seats = driver_H.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")


        for bus in bus_name:
            Bus_names_H.append(bus.text)
            Route_links.append(link)
            Route_names.append(routes)
        for bus_type_elem in bus_type:
            Bus_types_H.append(bus_type_elem.text)
        for start_time_elem in start_time:
            Start_Time_H.append(start_time_elem.text)
        for end_time_elem in end_time:
            End_Time_H.append(end_time_elem.text)
        for total_duration_elem in total_duration:
            Total_Duration_H.append(total_duration_elem.text)
        for ratings in rating:
            Ratings_H.append(ratings.text)
        for price_elem in price:
            Prices_H.append(price_elem.text)
        for seats_elem in seats:
            Seats_Available_H.append(seats_elem.text)

 
    print("Successfully Completed")
# Out:
# Successfully Completed

# %%
    import pandas as pd
    data= {
        'Bus_name': Bus_names_H,
        'Bus_type': Bus_types_H,
        'Start_time': Start_Time_H,
        'End_time': End_Time_H,
        'Total_duration':Total_Duration_H,
        'Price': Prices_H,
        "Seats_Available":Seats_Available_H,
        "Ratings":Ratings_H,
        'Route_link': Route_links,
        'Route_name': Route_names
    }

    df_buses_10 = pd.DataFrame(data)
    path="df_buses_10.csv"
    df=df_buses_10.to_csv(path,index=False)

# %%
df_buses_10
# Out:
#                 Bus_name                            Bus_type Start_time  \
# 0              HRTC - 69  Himsuta AC Seater Volvo/Scania 2+2      00:40
# 1               HRTC - 6  Himsuta AC Seater Volvo/Scania 2+2      06:45
# 2             HRTC - 592                 A/C Executive (2+3)      08:05
# 3             HRTC - 129          Ordinary 3+2 Non AC Seater      08:50
# 4               HRTC - 7  Himsuta AC Seater Volvo/Scania 2+2      09:25
# ..                   ...                                 ...        ...
# 381       Laxmi holidays   Volvo 9600 A/C Semi Sleeper (2+2)      16:00
# 382       Laxmi holidays   Volvo 9600 A/C Semi Sleeper (2+2)      22:00
# 383         Zingbus Plus   Volvo 9600 A/C Semi Sleeper (2+2)      21:00
# 384  AdIntrCity SmartBus   Volvo 9600 A/C Semi Sleeper (2+2)      18:15
# 385       Laxmi holidays   Volvo 9600 A/C Semi Sleeper (2+2)      21:00
#
#     End_time Total_duration    Price     Seats_Available   Ratings  \
# 0      09:30        08h 50m  INR 912  28 Seats available   4.7\n59
# 1      16:10        09h 25m  INR 912  32 Seats available   4.5\n60
# 2      18:10        10h 05m  INR 632  41 Seats available   2.7\n13
# 3      18:40        09h 50m  INR 512  37 Seats available    2.6\n4
# 4      18:30        09h 05m  INR 912  16 Seats available   4.4\n80
# ..       ...            ...      ...                 ...       ...
# 381    04:20        12h 20m      854  19 Seats available  4.7\n657
# 382    07:45        09h 45m      949  14 Seats available  4.6\n930
# 383    08:10        11h 10m      642  17 Seats available  4.8\n228
# 384    06:00        11h 45m  INR 748  28 Seats available  4.6\n333
# 385    08:00        11h 00m     1092  25 Seats available  4.6\n725
#
#                                             Route_link       Route_name
# 0    https://www.redbus.in/bus-tickets/delhi-to-shimla  Delhi to Shimla
# 1    https://www.redbus.in/bus-tickets/delhi-to-shimla  Delhi to Shimla
# 2    https://www.redbus.in/bus-tickets/delhi-to-shimla  Delhi to Shimla
# 3    https://www.redbus.in/bus-tickets/delhi-to-shimla  Delhi to Shimla
# 4    https://www.redbus.in/bus-tickets/delhi-to-shimla  Delhi to Shimla
# ..                                                 ...              ...
# 381  https://www.redbus.in/bus-tickets/manali-to-delhi  Manali to Delhi
# 382  https://www.redbus.in/bus-tickets/manali-to-delhi  Manali to Delhi
# 383  https://www.redbus.in/bus-tickets/manali-to-delhi  Manali to Delhi
# 384  https://www.redbus.in/bus-tickets/manali-to-delhi  Manali to Delhi
# 385  https://www.redbus.in/bus-tickets/manali-to-delhi  Manali to Delhi
#
# [386 rows x 10 columns]
